# %%
import pandas as pd
import requests
import re
import numpy as np

# %%
ucs_url = "https://www.ucsusa.org/media/11492"

ucs_xl = pd.read_excel(ucs_url, storage_options={'User-Agent': 'Chrome/51.0.2704.103'})
ucs_df = pd.DataFrame(ucs_xl)

ucs_dict = ucs_df.to_dict('list')

names = ucs_dict['Name of Satellite, Alternate Names']

# %%
friendly_names = []
alternate_names = []

for indName in names:
    name_list = indName.split("(")
    friendly = name_list[0].strip()
    if (len(name_list) == 1):
        alternate = 'null'
    else:
        alternate = name_list[1].split(")")[0].strip()

    friendly_names += [friendly]
    alternate_names += [alternate]

# %%
myDict = {'Friendly Name':friendly_names, 'Alternate Names':alternate_names,
        'Official Name':[str(x) for x in ucs_dict.pop('Current Official Name of Satellite')],
        'ID':[str(x) for x in ucs_dict.pop('NORAD Number')], 'Orbit Class':[str(x) for x in ucs_dict.pop('Class of Orbit')]}

# %%
myDict
# Out:
# {'Friendly Name': ['1HOPSAT-TD',
#   'Aalto-1',
#   'AAt-4',
#   'ABS-2',
#   'ABS-2A',
#   'ABS-3A',
#   'ABS-4',
#   'ABS-6',
#   'Adelis-Sampson 1',
#   'Adelis-Sampson 2',
#   'Adelis-Sampson 3',
#   'Advanced Orion 10',
#   'Advanced Orion 4',
#   'Advanced Orion 5',
#   'Advanced Orion 6',
#   'Advanced Orion 7',
#   'Advanced Orion 8',
#   'Advanced Orion 9',
#   'AEHF-3',
#   'AEHF-4',
#   'AEHF-5',
#   'AEHF-6',
#   'AEHF-USA 2',
#   'Aeneas',
#   'Aeolus',
#   'Aerocube 10A',
#   'Aerocube 10B',
#   'Aerocube 11A',
#   'Aerocube 11B',
#   'Aerocube 12A',
#   'Aerocube 12B',
#   'Aerocube 14A',
#   'Aerocube 14B',
#   'Aerocube 15A',
#   'Aerocube 5C',
#   'Aerocube 6A',
#   'Aerocube 6B',
#   'Aerocube 7A',
#   'Aerocube 8C',
#   'Aerocube 8D',
#   'Afghansat-1',
#   'AII-Bravo',
#   'AII-Charlie',
#   'AIM',
#   'AISSat-1',
#   'AISSat-2',
#   'AISTechSat-2',
#   'AISTechSat-3',
#   'Al Yah-3',
#   'Alcomsat',
#   'ALE-2',
#   'Alfa Crux',
#   'Al-Farabi-2',
#   'ALiCE',
#   'Alsat-1B',
#   'Alsat-1N',
#   'Alsat-2A',
#   'Alsat-2B',
#   'Amazonas-2',
#   'Amazonas-3',
#   'Amazonas-4A',
#   'Amazonas-5',
#   'Amazonia-1',
#   'AMC-1',
#   'AMC-11',
#   'AMC-15',
#   'AMC-18',
#   'AMC-21',
#   'AMC-4',
#   'AMC-6',
#   'AMC-8',
#   'AmGU-1',
#   'Amos 17',
#   'Amos 3',
#   'Amos 4',
#   'Amsat-Oscar 7',
#   'ANASIS-II',
#   'ANDESITE Mule',
#   'ANGELS',
#   'Angosat-2',
#   'Anik F1',
#   'Anik F1R',
#   'Anik F2',
#   'Anik F3',
#   'Anik G1',
#   'AprizeSat 1',
#   'AprizeSat 10',
#   'AprizeSat 2',
#   'AprizeSat 3',
#   'AprizeSat 4',
#   'AprizeSat 5',
#   'AprizeSat 7',
#   'AprizeSat 8',
#   'AprizeSat 9',
#   'Apstar 6C',
#   'Apstar 6D',
#   'Apstar 7',
#   'Apstar 9',
#   'Arabsat 5C',
#   'Arabsat 6A',
#   'ARCE 1A',
#   'ARCE 1B',
#   'ARCE 1C',
#   'ARCSAT',
#   'ARICA',
#   'Arktika-M1',
#   'Arkyd-6A',
#   'ArSat 1',
#   'ArSat 2',
#   'Arthur',
#   'ASELSAT',
#   'AsiaSat-5',
#   'AsiaSat-6',
#   'AsiaSat-7',
#   'AsiaSat-8',
#   'AsiaSat-9',
#   'AsiaStar',
#   'ASNARO 1',
#   'ASNARO 2',
#   'ASTERISC',
#   'Astra 1G',
#   'Astra 1KR',
#   'Astra 1L',
#   'Astra 1M',
#   'Astra 1N',
#   'Astra 2A',
#   'Astra 2C',
#   'Astra 2D',
#   'Astra 2E',
#   'Astra 2F',
#   'Astra 2G',
#   'Astra 3A',
#   'Astra 3B',
#   'Astra 5B',
#   'Astranis Demosat-2',
#   'Astrocast-0101',
#   'Astrocast-0102',
#   'Astrocast-0103',
#   'Astrocast-0104',
#   'Astrocast-0105',
#   'Astrocast-0201',
#   'Astrocast-0202',
#   'Astrocast-0203',
#   'Astrocast-0204',
#   'Astrocast-0205',
#   'Astrosat',
#   'AT&T T16',
#   'Athena',
#   'Athena-Fidus',
#   'Athenoxat-1',
#   'Azerspace 1/Africasat-1a',
#   'Azerspace 2/Intelsat-38',
#   'Badr 4',
#   'Badr 5',
#   'Badr 5A',
#   'Badr 6',
#   'Badr 7',
#   'Bangabandhu 1',
#   'Baoyun',
#   'BARS-M',
#   'BARS-M',
#   'BARS-M3',
#   'BDSAGR-1',
#   'BDSAT',
#   'Beesat-5',
#   'Beesat-6',
#   'Beesat-7',
#   'Beesat-8',
#   'Beesat-9',
#   'Beidou 2-12',
#   'Beidou 2-13',
#   'Beidou 2-15',
#   'Beidou 2-16',
#   'Beidou 2-17',
#   'Beidou 2-18',
#   'Beidou 3I-1S',
#   'Beidou 3I-2S',
#   'Beidou 3M1',
#   'Beidou 3M1',
#   'Beidou 3M1',
#   'Beidou 3M1',
#   'Beidou 3M-1S',
#   'Beidou 3M-2S',
#   'Beidou DW 26',
#   'Beidou DW 27',
#   'Beidou DW 28',
#   'Beidou DW 29',
#   'Beidou DW 30',
#   'Beidou DW 31',
#   'Beidou DW 32',
#   'Beidou DW 33',
#   'Beidou DW 34',
#   'Beidou DW 35',
#   'Beidou DW 36',
#   'Beidou DW 37',
#   'Beidou DW 38',
#   'Beidou DW 39',
#   'Beidou DW 40',
#   'Beidou DW 41',
#   'Beidou DW 42',
#   'Beidou DW 43',
#   'Beidou DW 44',
#   'Beidou DW 45',
#   'Beidou DW 46',
#   'Beidou DW 49',
#   'Beidou DW 50',
#   'Beidou DW 51',
#   'Beidou DW 52',
#   'Beidou DW 53',
#   'Beidou DW 55',
#   'Beidou G3',
#   'Beidou G4',
#   'Beidou G5',
#   'Beidou IGSO-1',
#   'Beidou IGSO-2',
#   'Beidou IGSO-3',
#   'Beidou IGSO-4',
#   'Beidou IGSO-5',
#   'Beijing-3',
#   'BeijingGalaxy-1',
#   'Belintersat-1',
#   'Bird 2',
#   'BIROS',
#   'BisonSat',
#   'BKA 2',
#   'BlackSky Global 1',
#   'BlackSky Global 14',
#   'BlackSky Global 15',
#   'BlackSky Global 16',
#   'BlackSky Global 17',
#   'BlackSky Global 18',
#   'BlackSky Global 2',
#   'BlackSky Global 20',
#   'BlackSky Global 3',
#   'BlackSky Global 4',
#   'BlackSky Global 7',
#   'BlackSky Global 8',
#   'BlackSky Global 9',
#   'BlackSky Pathfinder 1',
#   'Blagovest-11L',
#   'Blagovest-12L',
#   'Blagovest-13L',
#   'Blagovest-14L',
#   'Bluewalker 1',
#   'Bluewalker 3',
#   'Brazilsat B-4',
#   'Brik-II',
#   'BRIO',
#   'BRISat',
#   'BRITE-CA-1',
#   'BRITE-PL-2',
#   'BRO-1',
#   'BRO-4',
#   'BRO-7',
#   'BSAT-3A',
#   'BSAT-3B',
#   'BSAT-3C/JCSat 110-R',
#   'BSAT-4A',
#   'BSAT-4B',
#   'Buccaneer RMM',
#   'Bufeng-1A',
#   'Bufeng-1B',
#   'Bugsat-1',
#   'BulgariaSat-1',
#   'CACTUS-1',
#   'Calipso',
#   'CanX-2',
#   'CanX-4',
#   'CanX-5',
#   'CanX-7',
#   'CAPE-3',
#   'Capella-1',
#   'Capella-2',
#   'Capella-3',
#   'Capella-4',
#   'Capella-5',
#   'Capella-6',
#   'Capella-7',
#   'Capella-8',
#   'CartoSat 1',
#   'CartoSat 2',
#   'CartoSat 2A',
#   'CartoSat 2B',
#   'CartoSat 2C',
#   'CartoSat 2D',
#   'CartoSat 2E',
#   'CartoSat 2F',
#   'CartoSat 3',
#   'CAS500-1',
#   'Cassiope',
#   'CBAS-1',
#   'CBERS 4',
#   'CBERS 4A',
#   'CBNT-1',
#   'CBNT-2',
#   'CELTEE-1',
#   'Centauri-1',
#   'Centauri-2',
#   'Centispace-1-S1',
#   'CeReS',
#   'CERES 1',
#   'CERES 2',
#   'CERES 3',
#   'CE-SAT-1',
#   'CE-SAT-2B',
#   'Cesium Satellite 1',
#   'Cesium Satellite 2',
#   'CFOSat',
#   'Challenge One',
#   'Chandra X-Ray Observatory',
#   'Changshagaoxin',
#   'Chao Fenbianlu Duo Guangpu Chengxiang Weixing',
#   'Chaohu-1',
#   'CHASE',
#   'CHEOPS',
#   'CHOMPTT',
#   'Chuangxin 1-1',
#   'Chuangxin 1-2',
#   'Chuangxin 1-3',
#   'Chuangxin 1-4',
#   'Chuangxin-16A',
#   'Chuangxin-16B',
#   'Chuangxin-3',
#   'Cicero-10',
#   'Cicero-2',
#   'Cicero-2 OP1',
#   'Cicero-2 OP2',
#   'Cicero-3',
#   'Cicero-6',
#   'Cicero-7',
#   'Cicero-8',
#   'Ciel-2',
#   'CINEMA-1',
#   'CIRiS',
#   'CLIO',
#   'Cloudsat',
#   'CMS-1',
#   'CNCE-1',
#   'CNCE-3',
#   'Compass-2',
#   'COMS-1',
#   'COMSATBw-1',
#   'COMSATBw-2',
#   'Coriolis',
#   'CORVUS BC1',
#   'CORVUS BC2',
#   'CORVUS BC3',
#   'CORVUS BC4',
#   'CORVUS BC5',
#   'COSMIC 2-1',
#   'COSMIC 2-2',
#   'COSMIC 2-3',
#   'COSMIC 2-4',
#   'COSMIC 2-5',
#   'COSMIC 2-6',
#   'COSMIC-A',
#   'COSMIC-B',
#   'COSMIC-D',
#   'COSMIC-E',
#   'COSMIC-F',
#   'Cosmos 2504',
#   'Cosmos 2535',
#   'Cosmos 2536',
#   'Cosmos 2542',
#   'Cosmos 2543',
#   'Cosmos 3537',
#   'Cosmos 3538',
#   'COSMO-Skymed 1',
#   'COSMO-Skymed 2',
#   'COSMO-Skymed 3',
#   'COSMO-Skymed 4',
#   'COSMO-Skymed FM2',
#   'CP-10',
#   'Cryosat-2',
#   'CSG-1',
#   'CSIM-FD',
#   'CSO-1',
#   'CSO-2',
#   'Cubebug 2',
#   'CubeSail T',
#   'Cubesat XI-IV',
#   'CuPID',
#   'CUTE',
#   'CYGNSS FM01',
#   'CYGNSS FM02',
#   'CYGNSS FM03',
#   'CYGNSS FM04',
#   'CYGNSS FM05',
#   'CYGNSS FM06',
#   'CYGNSS FM07',
#   'CYGNSS FM08',
#   'D2/AtlaCom-1',
#   'Daichi-2',
#   'DAMPE',
#   'DaVinci',
#   'Dayun',
#   'DCBB',
#   'Deimos 1',
#   'Deimos 2',
#   'Dekart',
#   'Delfi-C3',
#   'DeMi',
#   'DhabiSat-1',
#   'DHFR',
#   'Diamond Blue',
#   'Diamond Green',
#   'Diamond Red',
#   'Dido-2',
#   'Dido-3',
#   'DirecTV-10',
#   'DirecTV-11',
#   'DirecTV-12',
#   'DirecTV-14',
#   'DirecTV-15',
#   'DirecTV-5',
#   'DirecTV-8',
#   'DirecTV-9S',
#   'Diwata-2B',
#   'DLR Tubsat',
#   'DMC 3-1',
#   'DMC 3-2',
#   'DMC 3-3',
#   'DMSat-1',
#   'DMSP 5D-2 F14',
#   'DMSP 5D-3 F15',
#   'DMSP 5D-3 F16',
#   'DMSP 5D-3 F17',
#   'DMSP 5D-3 F18',
#   'Dodona',
#   'DoT-1',
#   'Dove 2k-12',
#   'Dove 2k-15',
#   'Dove 2k-19',
#   'Dove 2k-32',
#   'Dove 2k-35',
#   'Dove 2k-39',
#   'Dove 2k-40',
#   'Dove 2k-7',
#   'Dove 2p-3',
#   'Dove 2p-8',
#   'Dove 2p-9',
#   'Dove 3k-10',
#   'Dove 3k-4',
#   'Dove 3k-5',
#   'Dove 3k-7',
#   'Dove 3k-9',
#   'Dove 3m-4',
#   'Dove 3p-11',
#   'Dove 3p-12',
#   'Dove 3p-2',
#   'Dove 3p-23',
#   'Dove 3p-3',
#   'Dove 3p-32',
#   'Dove 3p-33',
#   'Dove 3p-34',
#   'Dove 3p-4',
#   'Dove 3p-46',
#   'Dove 3p-49',
#   'Dove 3p-50',
#   'Dove 3p-54',
#   'Dove 3p-55',
#   'Dove 3p-57',
#   'Dove 3p-58',
#   'Dove 3p-61',
#   'Dove 3p-64',
#   'Dove 3p-65',
#   'Dove 3p-66',
#   'Dove 3p-74',
#   'Dove 3p-76',
#   'Dove 3p-80',
#   'Dove 3r-1',
#   'Dove 3r-11',
#   'Dove 3r-12',
#   'Dove 3r-4',
#   'Dove 3r-6',
#   'Dove 3r-7',
#   'Dove 3r-9',
#   'Dove 3s-1',
#   'Dove 4a-17',
#   'Dove 4a-19',
#   'Dove 4a-2',
#   'Dove 4a-5',
#   'Dove 4a-9',
#   'Dove 4e’-1',
#   'Dove 4e’-2',
#   'Dove 4e’-3',
#   'Dove 4e’-4',
#   'Dove 4e’-5',
#   'Dove 4e’-6',
#   'Dove 4e’-7',
#   'Dove 4e’-8',
#   'Dove 4e’-9',
#   'Dove 4p-1',
#   'Dove 4p-10',
#   'Dove 4p-11',
#   'Dove 4p-3',
#   'Dove 4p-4',
#   'Dove 4p-5',
#   'Dove 4p-7',
#   'Dove 4s-1',
#   'Dove 4s-10',
#   'Dove 4s-11',
#   'Dove 4s-12',
#   'Dove 4s-13',
#   'Dove 4s-14',
#   'Dove 4s-15',
#   'Dove 4s-16',
#   'Dove 4s-17',
#   'Dove 4s-18',
#   'Dove 4s-19',
#   'Dove 4s-2',
#   'Dove 4s-20',
#   'Dove 4s-21',
#   'Dove 4s-22',
#   'Dove 4s-23',
#   'Dove 4s-24',
#   'Dove 4s-25',
#   'Dove 4s-27',
#   'Dove 4s-28',
#   'Dove 4s-3',
#   'Dove 4s-30',
#   'Dove 4s-31',
#   'Dove 4s-33',
#   'Dove 4s-34',
#   'Dove 4s-35',
#   'Dove 4s-36',
#   'Dove 4s-37',
#   'Dove 4s-39',
#   'Dove 4s-4',
#   'Dove 4s-41',
#   'Dove 4s-42',
#   'Dove 4s-43',
#   'Dove 4s-44',
#   'Dove 4s-45',
#   'Dove 4s-46',
#   'Dove 4s-47',
#   'Dove 4s-48',
#   'Dove 4s-5',
#   'Dove 4s-6',
#   'Dove 4s-7',
#   'Dove 4s-8',
#   'Dove 4s-9',
#   'Dove 4v-1',
#   'Dove 4v-10',
#   'Dove 4v-11',
#   'Dove 4v-13',
#   'Dove 4v-14',
#   'Dove 4v-15',
#   'Dove 4v-16',
#   'Dove 4v-17',
#   'Dove 4v-18',
#   'Dove 4v-19',
#   'Dove 4v-20',
#   'Dove 4v-22',
#   'Dove 4v-23',
#   'Dove 4v-24',
#   'Dove 4v-25',
#   'Dove 4v-26',
#   'Dove 4v-4',
#   'Dove 4v-5',
#   'Dove 4v-6',
#   'Dove 4v-7',
#   'Dove 4v-8',
#   'Dove 4x-1',
#   'Dove 4x-10',
#   'Dove 4x-11',
#   'Dove 4x-12',
#   'Dove 4x-13',
#   'Dove 4x-14',
#   'Dove 4x-15',
#   'Dove 4x-16',
#   'Dove 4x-17',
#   'Dove 4x-18',
#   'Dove 4x-19',
#   'Dove 4x-2',
#   'Dove 4x-20',
#   'Dove 4x-21',
#   'Dove 4x-22',
#   'Dove 4x-24',
#   'Dove 4x-25',
#   'Dove 4x-26',
#   'Dove 4x-28',
#   'Dove 4x-29',
#   'Dove 4x-3',
#   'Dove 4x-30',
#   'Dove 4x-31',
#   'Dove 4x-32',
#   'Dove 4x-34',
#   'Dove 4x-35',
#   'Dove 4x-36',
#   'Dove 4x-37',
#   'Dove 4x-38',
#   'Dove 4x-39',
#   'Dove 4x-4',
#   'Dove 4x-40',
#   'Dove 4x-41',
#   'Dove 4x-42',
#   'Dove 4x-43',
#   'Dove 4x-44',
#   'Dove 4x-5',
#   'Dove 4x-6',
#   'Dove 4x-7',
#   'Dove 4x-8',
#   'Dove 4x-9',
#   'DQ-1',
#   'DRUMS',
#   'DSCS III-A3',
#   'DSCS III-B6',
#   'DSCS III-F10',
#   'DSCS III-F12',
#   'DSCS III-F9',
#   'DSCS III-FUSA 11',
#   'DS-EO',
#   'DSP 20',
#   'DSP 21',
#   'DSP 22',
#   'D-Star ONE Sparrow',
#   'DSX',
#   'DubaiSat-2',
#   'Duogongneng Shiyan Weixing',
#   'Eagle-1',
#   'Eaglet-1',
#   'Echostar 10',
#   'Echostar 11',
#   'Echostar 14',
#   'Echostar 15',
#   'Echostar 16',
#   'Echostar 17',
#   'Echostar 18',
#   'Echostar 19',
#   'Echostar 21',
#   'Echostar 23',
#   'Echostar 7',
#   'Echostar 9/Galaxy 23',
#   'Echostar G1',
#   'Ecuador-UTE',
#   'EDRS-C',
#   'EgyptSat-A',
#   'EKS-1',
#   'EKS-2',
#   'EKS-3',
#   'EKS-4',
#   'EKS-5',
#   'El Camino Real',
#   'Electro-L1',
#   'Electro-L2',
#   'Electro-L3',
#   'ELFIN-Star',
#   'ELISA-E12',
#   'ELISA-E24',
#   'ELISA-W11',
#   'ELISA-W23',
#   'ELSA-d',
#   'EMISat',
#   'EnMAP',
#   'EOS-1',
#   'EOS-4',
#   'EOS-AM Terra',
#   'EOS-CHEM Aura',
#   'EOS-PM Aqua',
#   'ERA-1',
#   'ERG',
#   'EROS B1',
#   'ESAIL Maritime Microsatellite',
#   'ESEO',
#   "Es'hail-1",
#   "Es'hail-2",
#   'E-Space 1',
#   'E-Space 2',
#   'E-Space 3',
#   'ESPASat',
#   'ETRSS-1',
#   'ET-SMART-RSS',
#   'Eu:CROPIS',
#   'Eutelsat 10A',
#   'Eutelsat 113 West A',
#   'Eutelsat 115 West B',
#   'Eutelsat 117 West A',
#   'Eutelsat 117 West B',
#   'Eutelsat 133 West A',
#   'Eutelsat 139 West A',
#   'Eutelsat 16A',
#   'Eutelsat 172B',
#   'Eutelsat 174A',
#   'Eutelsat 21B',
#   'Eutelsat 33E',
#   'Eutelsat 36A',
#   'Eutelsat 36B',
#   'Eutelsat 3B',
#   'Eutelsat 5 West A',
#   'Eutelsat 5 West B',
#   'Eutelsat 65 West A',
#   'Eutelsat 7 West A',
#   'Eutelsat 70B',
#   'Eutelsat 7B',
#   'Eutelsat 7C',
#   'Eutelsat 8 West B',
#   'Eutelsat 9B',
#   'Eutelsat Hot Bird 13B',
#   'Eutelsat Hot Bird 13C',
#   'Eutelsat Hot Bird 13E',
#   'Eutelsat Hotbird 13F',
#   'Eutelsat Hotbird 13G',
#   'Eutelsat KA-SAT 9A',
#   'Eutelsat Konnect',
#   'Eutelsat Konnect VHTS',
#   'Eutelsat Quantum',
#   'exactView 6',
#   'exactView 9',
#   'eXCITE',
#   'ExoCube-2',
#   'Express-103',
#   'Express-80',
#   'Express-AM3',
#   'Express-AM33',
#   'Express-AM44',
#   'Express-AM5',
#   'Express-AM6',
#   'Express-AM7',
#   'Express-AM8',
#   'Express-AMU1',
#   'Express-AMU3',
#   'Express-AMU7',
#   'Express-AT1',
#   'Express-AT2',
#   'ExSeedSat-1',
#   'Eyesat',
#   'FACSAT-1',
#   'FalconEye-2',
#   'Falconsat-3',
#   'Falconsat-6',
#   'Falconsat-7',
#   'Falconsat-8',
#   'Faraday Phoenix',
#   'FAST 1',
#   'Fengmaniu-1',
#   'Fengniao 1A',
#   'Fengyun 2F',
#   'Fengyun 2G',
#   'Fengyun 2H',
#   'Fengyun 3B',
#   'Fengyun 3C',
#   'Fengyun 3D',
#   'Fengyun 3E',
#   'Fengyun 4A',
#   'Fengyun 4B',
#   'Fermi Gamma-Ray Space Telescope',
#   'FIA Radar 1',
#   'FIA Radar 2',
#   'FIA Radar 3',
#   'FIA Radar 4',
#   'FIA Radar 5',
#   'Firebird-C',
#   'Firebird-D',
#   'FLP',
#   'FLTSATCOM-8',
#   'FormoSat-5',
#   'FORTÉ',
#   'Foshan 1',
#   'FossaSat -2E2',
#   'FossaSat-2E1',
#   'FossaSat-2E3',
#   'FossaSat-2E4',
#   'FossaSat-2E5',
#   'FossaSat-2E6',
#   'Fox-1Cliff',
#   'FSSCAT-A',
#   'FSSCAT-B',
#   'FUNCube-1',
#   'Galaxy-11',
#   'Galaxy-12',
#   'Galaxy-13',
#   'Galaxy-14',
#   'Galaxy-15',
#   'Galaxy-16',
#   'Galaxy-17',
#   'Galaxy-18',
#   'Galaxy-19',
#   'Galaxy-25',
#   'Galaxy-28',
#   'Galaxy-30',
#   'Galaxy-33',
#   'Galaxy-34',
#   'Galaxy-3C',
#   'Galileo FOC FM1',
#   'Galileo FOC FM10',
#   'Galileo FOC FM11',
#   'Galileo FOC FM12',
#   'Galileo FOC FM13',
#   'Galileo FOC FM14',
#   'Galileo FOC FM15',
#   'Galileo FOC FM16',
#   'Galileo FOC FM17',
#   'Galileo FOC FM18',
#   'Galileo FOC FM19',
#   'Galileo FOC FM2',
#   'Galileo FOC FM20',
#   'Galileo FOC FM21',
#   'Galileo FOC FM22',
#   'Galileo FOC FM23',
#   'Galileo FOC FM24',
#   'Galileo FOC FM3',
#   'Galileo FOC FM4',
#   'Galileo FOC FM5',
#   'Galileo FOC FM6',
#   'Galileo FOC FM7',
#   'Galileo FOC FM8',
#   'Galileo FOC FM9',
#   'Galileo IOV-1 FM2',
#   'Galileo IOV-1 PFM',
#   'Galileo IOV-2 FM3',
#   'Galileo IOV-2 FM4',
#   'Gaofen 1',
#   'Gaofen 10',
#   'Gaofen 1-02',
#   'Gaofen 1-03',
#   'Gaofen 1-04',
#   'Gaofen 1-05',
#   'Gaofen 1-06',
#   'Gaofen 11',
#   'Gaofen 11-02',
#   'Gaofen 11-03',
#   'Gaofen 12',
#   'Gaofen 12-02',
#   'Gaofen 12-03',
#   'Gaofen 13',
#   'Gaofen 14',
#   'Gaofen 2',
#   'Gaofen 3',
#   'Gaofen 3-02',
#   'Gaofen 3-03',
#   'Gaofen 4',
#   'Gaofen 5-02',
#   'Gaofen 7',
#   'Gaofen 8',
#   'Gaofen 9',
#   'Gaofen 9-02',
#   'Gaofen 9-03',
#   'Gaofen 9-04',
#   'Gaofen 9-05',
#   'Gaofen Multi-Mode 1',
#   'Garpun-12L',
#   'GATOSS',
#   'GCOM-C',
#   'GEARRS-3',
#   'GEARRSAT-2',
#   'GECAM-A',
#   'GECAM-B',
#   'GeeSat 5-01',
#   'GeeSat 5-02',
#   'GeeSat 5-03',
#   'GeeSat 5-04',
#   'GeeSat 5-05',
#   'GeeSat 5-06',
#   'GeeSat 5-07',
#   'GeeSat 5-08',
#   'GeeSat 5-09',
#   'Genesis-1',
#   'Genesis-2',
#   'GEO IK2 12L',
#   'GEO IK2 13L',
#   'GeoEye-1',
#   'GEO-Kompsat-2A',
#   'GEO-Kompsat-2B',
#   'Geotail',
#   'Ghalib',
#   'GHGSat-C1',
#   'GHGSat-C2',
#   'GHGSat-D',
#   'Global Change Observation Mission - 1 Water',
#   'Globalstar FM15',
#   'Globalstar M037',
#   'Globalstar M065',
#   'Globalstar M066',
#   'Globalstar M067',
#   'Globalstar M069',
#   'Globalstar M070',
#   'Globalstar M071',
#   'Globalstar M072',
#   'Globalstar M073',
#   'Globalstar M074',
#   'Globalstar M075',
#   'Globalstar M076',
#   'Globalstar M077',
#   'Globalstar M078',
#   'Globalstar M079',
#   'Globalstar M080',
#   'Globalstar M081',
#   'Globalstar M082',
#   'Globalstar M083',
#   'Globalstar M084',
#   'Globalstar M085',
#   'Globalstar M086',
#   'Globalstar M088',
#   'Globalstar M089',
#   'Globalstar M090',
#   'Globalstar M091',
#   'Globalstar M092',
#   'Globalstar M093',
#   'Globalstar M094',
#   'Globalstar M095',
#   'Globalstar M096',
#   'Globalstar M097',
#   'Glonass',
#   'Glonass 701',
#   'Glonass 702',
#   'Glonass 705',
#   'Glonass 706',
#   'Glonass 716',
#   'Glonass 717',
#   'Glonass 719',
#   'Glonass 720',
#   'Glonass 721',
#   'Glonass 723',
#   'Glonass 730',
#   'Glonass 731',
#   'Glonass 732',
#   'Glonass 733',
#   'Glonass 735',
#   'Glonass 736',
#   'Glonass 743',
#   'Glonass 744',
#   'Glonass 745',
#   'Glonass 747',
#   'Glonass 751',
#   'Glonass 752',
#   'Glonass 753',
#   'Glonass 755',
#   'Glonass 756',
#   'Glonass 757',
#   'Glonass 758',
#   'Glonass 759',
#   'Glonass 760',
#   'GMS-T',
#   'GNOMES-1',
#   'GNOMES-2',
#   'GNOMES-3',
#   'GOES 13',
#   'GOES 14',
#   'GOES 15',
#   'GOES 16',
#   'GOES 17',
#   'GOES 18',
#   'Göktürk 1',
#   'Göktürk 2',
#   'Golden Bauhinia 1-03',
#   'Golden Bauhinia 5',
#   'GomX-4A',
#   'GomX-4B',
#   'Gonets M-11',
#   'Gonets M-12',
#   'Gonets M-13',
#   'Gonets M-14',
#   'Gonets M-16',
#   'Gonets M-17',
#   'Gonets M-18',
#   'Gonets M-19',
#   'Gonets M-20',
#   'Gonets M-24',
#   'Gonets M-25',
#   'Gonets M-26',
#   'Gonets M-27',
#   'Gonets M-28',
#   'Gonets M-29',
#   'Gonets M-30',
#   'Gonets M-31',
#   'Gonets M-32',
#   'GOSAT-2',
#   'Gossamer Piccolomini',
#   'GovSat-1',
#   'GPM Core Observatory',
#   'Grace Follow-on-1',
#   'Grace Follow-on-2',
#   'Greenhouse Gases Observing Satellite',
#   'GRUS-1A',
#   'GRUS-1B',
#   'GRUS-1C',
#   'GRUS-1D',
#   'GRUS-1E',
#   'GSAT-10',
#   'GSAT-11',
#   'GSAT-12',
#   'GSAT-14',
#   'GSAT-15',
#   'GSAT-16',
#   'GSAT-17',
#   'GSAT-18',
#   'GSAT-19E',
#   'GSAT-24',
#   'GSAT-29',
#   'GSAT-30',
#   'GSAT-31',
#   'GSAT-6',
#   'GSAT-7',
#   'GSAT-7A',
#   'GSAT-8',
#   'GSSAP 2',
#   'GSSAP 3',
#   'GSSAP 4',
#   'GSSAP 5',
#   ...],
#  'Alternate Names': ['1st-generation High Optical Performance Satellite',
#   'null',
#   'null',
#   'Koreasat-8, ST-3',
#   'null',
#   'null',
#   'ABS-2i, MBSat, Mobile Broadcasting Satellite, Han Byul',
#   'ABS-1, LMI-1, Lockheed Martin-Intersputnik-1',
#   'null',
#   'null',
#   'null',
#   'Mentor, NRO L-44, USA 311',
#   'Mentor, NROL 6, USA 139',
#   'Mentor, NROL 19, USA 171',
#   'Mentor, NRO L-26, USA 202',
#   'Mentor, NRO L-32, USA 223',
#   'Mentor, NRO L-15, USA 237',
#   'Mentor, NRO L-37, USA 268',
#   'Advanced Extremely High Frequency satellite-3, USA 246',
#   'Advanced Extremely High Frequency satellite-4, USA 288',
#   'Advanced Extremely High Frequency satellite-5, USA 29USA 2',
#   'Advanced Extremely High Frequency satellite-6, USA 298',
#   'Advanced Extremely High Frequency satellite-USA 2, USA 235',
#   'null',
#   'null',
#   'Jimsat',
#   'Dougsat',
#   'TOMSat Eagle Scout',
#   'TOMSat R3',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Eutelsat 48D [Eutelsat 48B, Eutelsat W2M]',
#   'null',
#   'null',
#   'Aeronomy of Ice in Mesosphere',
#   'Automatic Identification System Satellite-1',
#   'Automatic Identification System Satellite-2',
#   'null',
#   'null',
#   'null',
#   'Algerian Communications Satellite',
#   'Astro Live Experiences-2',
#   'null',
#   'null',
#   'AFIT LEO iMESA CNT E',
#   'null',
#   'null',
#   'Algeria Satellite 2A',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'SSR-1',
#   'Americom 1, GE-1',
#   'Americom-11, GE 11',
#   'Americom-15',
#   'Americom 18',
#   'Americom 21',
#   'Americom-4, GE-4',
#   'Americom-6, GE-6',
#   'Americom-8, GE-8, Aurora 3',
#   'AmurSat-1',
#   'null',
#   'null',
#   'null',
#   'AO-7',
#   'Army, Navy Air Force Satellite Information System 2, KMilSatCom 1',
#   'Ad-Hoc Network Demonstration for Extended Satellite-Based Inquiry and Other Team Endeavors',
#   'Argos Neo on a Generic Economical and Light Satellite',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'LatinSat-C',
#   'exactView-13',
#   'LatinSat-D',
#   'null',
#   'null',
#   'null',
#   'null',
#   'exactView-12',
#   'exactView-11',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Articulated Reconnaissance and Communications Expedition-1',
#   'Articulated Reconnaissance and Communications Expedition-1',
#   'Articulated Reconnaissance and Communications Expedition-1',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Thaicom-7',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Advanced Satellite with New system Architecture for Observation',
#   'Advanced Satellite with New system Architecture for Observation',
#   'Asutarisuku',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Eutelsat 28E',
#   'Eutelsat 28F',
#   'Eutelsat 28G',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Access on THeatres for European Nations Allied forces - French Italian Dual Use Satellite',
#   'Athene Noctua Experimental Satellite',
#   'null',
#   'null',
#   'Arabsat 4B',
#   'Arabsat 5B',
#   'Arabsat 5A',
#   'Arabsat 4AR',
#   'Arabsat 6B',
#   'null',
#   'null',
#   'Cosmos 2503',
#   'Cosmos 2515',
#   'Cosmos 2556',
#   'null',
#   'CZE-BDSAT',
#   'Berlin Experimental and Educational Satellite-5',
#   'Berlin Experimental and Educational Satellite-6',
#   'Berlin Experimental and Educational Satellite-7',
#   'Berlin Experimental and Educational Satellite-8',
#   'Berlin Experimental and Educational Satellite-9, Tubsat-17',
#   'Compass M3',
#   'Compass M4',
#   'Compass M6',
#   'Compass G-6',
#   'IGSO-6',
#   'Compass G-7',
#   'null',
#   'null',
#   'null',
#   'Beidou 23',
#   'Beidou 24',
#   'Beidou 25',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Compass G-3',
#   'Compass G-4',
#   'Compass G-11',
#   'Compass G-5',
#   'Compass G-7',
#   'Compass G-8',
#   'Compass G-9',
#   'Compass G-10',
#   'null',
#   'Beijing 1 [Tsinghua], Tsinghau-2, China DMC+4',
#   'null',
#   'Bispectral InfraRed Detector 2',
#   'Bispectral Infrared Optical System',
#   'Nwist Qwiqway',
#   'BelKA 2',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Cosmos 2520',
#   'Cosmos 2526',
#   'Cosmos 2533',
#   'Cosmos 2539',
#   'null',
#   'null',
#   'Brasilsat B-4',
#   'null',
#   'null',
#   'null',
#   'BRITE Toronto',
#   'BRIght-star Target Explorer - Poland, Hevelius',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Tita',
#   'null',
#   'Coordinated Applied Capitol Technology University Satellite 1',
#   'Cloud-Aerosol Lidar and Infrared Pathfinder Satellite Observation',
#   'Canadian Advanced Nanospace experiment',
#   'null',
#   'null',
#   'null',
#   'Cajun Advanced Picosatellite Experiment-3',
#   'Denali',
#   'Sequoia',
#   'Whitney 1',
#   'Whitney 2',
#   'Whitney 3',
#   'Whitney 4',
#   'Whitney 5',
#   'Whitney 6',
#   'IRS P5',
#   'IRS P7, CartoSat 2AT',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'CAScade SmallSat and Ionospheric Polar Explorer',
#   'USA 283, Continuous Broadcast Augmenting SATCOM-1',
#   'China-Brazil Earth Resources Satellite 4',
#   'China-Brazil Earth Resources Satellite 4A',
#   'Carbonite 1',
#   'Carbonite 2',
#   'CubeSat Enhanced Locator Transponder Evaluation Experiment-1',
#   'null',
#   'null',
#   'null',
#   'Compact Radiation belt Explorer',
#   'CapacitÉ de Renseignement Électromagnétique Spatiale',
#   'CapacitÉ de Renseignement Électromagnétique Spatiale',
#   'CapacitÉ de Renseignement Électromagnétique Spatiale',
#   'Canon Electric Satellite 1',
#   'Canon Electric Satellite 2B',
#   'null',
#   'null',
#   'China-France Oceanography Satellite',
#   'null',
#   'CXO',
#   'TY 4-01',
#   'Ultra-resolution multispectral imaging satellite',
#   'null',
#   'Chinese Hydrogen Alpha Solar Explorer, Xihe',
#   'CHaracterising ExOPlanet Satellite',
#   'CubeSat Handling Of Multisystem Precision Time Transfer',
#   'Innovation 1-1, Chuang Xin 1, CX-1-1',
#   'Innovation 1-2',
#   'Innovation 1-3',
#   'Innovation 1-4',
#   'null',
#   'null',
#   'null',
#   'Community Initiative for Cellular Earth Remote Observation-10',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Community Initiative for Cellular Earth Remote Observation-6',
#   'Community Initiative for Cellular Earth Remote Observation-7',
#   'Community Initiative for Cellular Earth Remote Observation-8',
#   'null',
#   'Cubesat for Ion, Neutral, Electron, Magnetic fields',
#   'Compact Radiometer in Space',
#   'USA 257',
#   'null',
#   'GSAT 12R',
#   'null',
#   'null',
#   'QB50-DE04',
#   'Communication, Ocean and Meteorological Satellite; Cheollian',
#   'COmmunications SATellite für BundesWehr',
#   'COmmunications SATellite für BundesWehr',
#   'Windsat',
#   'Landmapper',
#   'Landmapper',
#   'Landmapper',
#   'Landmapper',
#   'Landmapper',
#   'COSMIC FM-1, Formosat 7A',
#   'COSMIC FM-2, Formosat 7B',
#   'COSMIC FM-3, Formosat 7C',
#   'COSMIC FM-4, Formosat 7D',
#   'COSMIC FM-5, Formosat 7E',
#   'COSMIC FM-6, Formosat 7F',
#   'Formosat-3A, Constellation Observing System for Meteorology, Ionosphere and Climate',
#   'Formosat-3B, Constellation Observing System for Meteorology, Ionosphere and Climate',
#   'Formosat-3D, Constellation Observing System for Meteorology, Ionosphere and Climate',
#   'Formosat-3E, Constellation Observing System for Meteorology, Ionosphere and Climate',
#   'Formosat-3F, Constellation Observing System for Meteorology, Ionosphere and Climate',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Constellation of small Satellites for Mediterranean basin Observation',
#   'Constellation of small Satellites for Mediterranean basin Observation',
#   'Constellation of small Satellites for Mediterranean basin Observation',
#   'Constellation of small Satellites for Mediterranean basin Observation',
#   'null',
#   'Exocube',
#   'null',
#   'COSMO-SkyMed Second Generation',
#   'Compact Spectral Irradiance Monitor - Flight Demonstration',
#   'Optical Space Component-1',
#   'Optical Space Component-2',
#   'Manolito, LO-74',
#   'null',
#   'Oscar 57, CO-57',
#   'Cusp Plasma Imaging Detector',
#   'Colorado Ultraviolet Transit Experiment',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'Cyclone Global Navigation Satellite System',
#   'null',
#   'Advanced Land Observing Satellite-2, ALOS 2 2',
#   'Dark Matter Particle Explorer',
#   'null',
#   'Starera 17, Xingshidai 17',
#   'Kaituo-1B, CAS-3G',
#   'null',
#   'null',
#   'Descartes',
#   'DO-64',
#   'Deformable Mirror',
#   'null',
#   'DARPA High Frequency Receiver',
#   '3 Diamonds 1',
#   '3 Diamonds 2',
#   '3 Diamonds 3',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Tempo 1',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Disaster Monitoring Constellation',
#   'Disaster Monitoring Constellation',
#   'Disaster Monitoring Constellation',
#   'Dubai Municipality Satellite',
#   'Defense Meteorological Satellites Program, USA 131',
#   'Defense Meteorological Satellites Program, USA 147',
#   'Defense Meteorological Satellites Program, USA 172',
#   'Defense Meteorological Satellites Program, USA 173',
#   'Defense Meteorological Satellites Program, USA 210',
#   'null',
#   'Demonstration of Technology 1',
#   '0 Flock 2K-12 0F36',
#   '0 Flock 2K-15 0F3C',
#   '0 Flock 2K-19 0F46',
#   '0 Flock 2K-32 104B',
#   '0 Flock 2K-35 104E',
#   '0 Flock 2K-39 1052',
#   '0 Flock 2K-40 1053',
#   '0 Flock 2K-7 0F2B',
#   '0 Flock 2P-3',
#   '0 Flock 2P-8 0E20',
#   '0 Flock 2P-9 0E26',
#   '0 Flock 3K-10 106d',
#   '0 Flock 3K-4 1063',
#   '0 Flock 3K-5 1067',
#   '0 Flock 3K-7 106a',
#   '0 Flock 3K-9 1065',
#   '0 Flock 3M-4 0F4C',
#   '0 Flock 3P-11 101F',
#   '0 Flock 3P-12 1010',
#   '0 Flock 3P-2 1001',
#   '0 Flock 3P-23 1025',
#   '0 Flock 3P-3 1002',
#   '0 Flock 3P-32 1035',
#   '0 Flock 3P-33 103C',
#   '0 Flock 3P-34 103B',
#   '0 Flock 3P-4 1003',
#   '0 Flock 3P-46 1011',
#   '0 Flock 3P-49 1038',
#   '0 Flock 3P-50 1034',
#   '0 Flock 3P-54 1005',
#   '0 Flock 3P-55 1008',
#   '0 Flock 3P-57 1014',
#   '0 Flock 3P-58 1009',
#   '0 Flock 3P-61 1012',
#   '0 Flock 3P-64 100A',
#   '0 Flock 3P-65 1040',
#   '0 Flock 3P-66 1013',
#   '0 Flock 3P-74 0F22',
#   '0 Flock 3P-76 0F17',
#   '0 Flock 3P-80 0F4E',
#   '0 Flock 3R-1 105A',
#   '0 Flock 3R-11 1064',
#   '0 Flock 3R-12 1066',
#   '0 Flock 3R-4 105E',
#   '0 Flock 3R-6 1057',
#   '0 Flock 3R-7 1058',
#   '0 Flock 3R-9 1061',
#   '0 Flock 3S-1 105C',
#   '0 Flock 4a-17 2212',
#   '0 Flock 4a-19 2235',
#   '0 Flock 4a-2 2201',
#   '0 Flock 4a-5 2227',
#   '0 Flock 4a-9 2224',
#   "0 Flock 4e'-1 225A",
#   "0 Flock 4e'-2 2279",
#   "0 Flock 4e'-3 2251",
#   "0 Flock 43'-4 227E",
#   "0 Flock 4e'-5 2276",
#   "0 Flock 4e'-6 2280",
#   "0 Flock 4e'-7 2262",
#   "0 Flock 4e'-8 2264",
#   "0 Flock 4e'-9 2441",
#   '0 Flock 4p-1 2277',
#   '0 Flock 4p-10 2233',
#   '0 Flock 4p-11 2231',
#   '0 Flock 4p-3 2304',
#   '0 Flock 4p-4 2310',
#   '0 Flock 4p-5 2259',
#   '0 Flock 4p-7 222F',
#   '0 Flock 4s-1 2436',
#   '0 Flock 4s-10 2449',
#   '0 Flock 4s-11 2445',
#   '0 Flock 4s-12 241A',
#   '0 Flock 4s-13 2453',
#   '0 Flock 4s-14 241F',
#   '0 Flock 4s-15 242F',
#   '0 Flock 4s-16 2434',
#   '0 Flock 4s-17 2432',
#   '0 Flock 4s-18 2421',
#   '0 Flock 4s-19 242D',
#   '0 Flock 4s-2 2428',
#   '0 Flock 4s-20 2439',
#   '0 Flock 4s-21 245C',
#   '0 Flock 4s-22 421E',
#   '0 Flock 4s-23 245D',
#   '0 Flock 4s-24 2431',
#   '0 Flock 4s-25 2448',
#   '0 Flock 4s-27 2457',
#   '0 Flock 4s-28 2460',
#   '0 Flock 4s-3 2433',
#   '0 Flock 4s-30 2459',
#   '0 Flock 4s-31 241B',
#   '0 Flock 4s-33 2420',
#   '0 Flock 4s-34 2464',
#   '0 Flock 4s-35 242A',
#   '0 Flock 4s-36 241D',
#   '0 Flock 4s-37 2429',
#   '0 Flock 4s-39 2458',
#   '0 Flock 4s-4 242B',
#   '0 Flock 4s-41 2427',
#   '0 Flock 4s-42 2430',
#   '0 Flock 4s-43 2435',
#   '0 Flock 4s-44 2440',
#   '0 Flock 4s-45 2442',
#   '0 Flock 4s-46 2444',
#   '0 Flock 4s-47 2456',
#   '0 Flock 4s-48 2465',
#   '0 Flock 4s-5 2423',
#   '0 Flock 4s-6 2455',
#   '0 Flock 4s-7 2451',
#   '0 Flock 4s-8 2450',
#   '0 Flock 4s-9 2447',
#   '0 Flock 4v-1 227C',
#   '0 Flock 4v-10 2254',
#   '0 Flock 4v-11 2424',
#   '0 Flock 4v-13 241C',
#   '0 Flock 4v-14 227A',
#   '0 Flock 4v15 2402',
#   '0 Flock 4v16 2403',
#   '0 Flock 4v17 2426',
#   '0 Flock 4v18 2413',
#   '0 Flock 4v19 2414',
#   '0 Flock 4v20 2406',
#   '0 Flock 4v22 240a',
#   '0 Flock 4v23 2401',
#   '0 Flock 4v24 2405',
#   '0 Flock 4v25 240C',
#   '0 Flock 4v26 2407',
#   '0 Flock 4v-4 2274',
#   '0 Flock 4v-5 240F',
#   '0 Flock 4v-6 225B',
#   '0 Flock 4v-7 227B',
#   '0 Flock 4v-8 2416',
#   '0 Flock 4x-1 2473',
#   '0 Flock 4x-10 249a',
#   '0 Flock 4x-11 249b',
#   '0 Flock 4x-12 2498',
#   '0 Flock 4x-13 249c',
#   '0 Flock 4x-14 2489',
#   '0 Flock 4x-15 2492',
#   '0 Flock 4x-16 2484',
#   '0 Flock 4x-17 247a',
#   '0 Flock 4x-18 249d',
#   '0 Flock 4x-19 247e',
#   '0 Flock 4x-2 2477',
#   '0 Flock 4x-20 2495',
#   '0 Flock 4x-21 2485',
#   '0 Flock 4x-22 2479',
#   '0 Flock 4x-24 248b',
#   '0 Flock 4x-25 24a3',
#   '0 Flock 4x-26 2490',
#   '0 Flock 4x-28 24a5',
#   '0 Flock 4x-29 247f',
#   '0 Flock 4x-3 2482',
#   '0 Flock 4x-30 24a4',
#   '0 Flock 4x-31 2499',
#   '0 Flock 4x-32 249e',
#   '0 Flock 4x-34 247d',
#   '0 Flock 4x-35 2461',
#   '0 Flock 4x-36 2446',
#   '0 Flock 4x-37 2481',
#   '0 Flock 4x-38 248f',
#   '0 Flock 4x-39 2475',
#   '0 Flock 4x-4 2483',
#   '0 Flock 4x-40 248e',
#   '0 Flock 4x-41 2488',
#   '0 Flock 4x-42 2480',
#   '0 Flock 4x-43 2486',
#   '0 Flock 4x-44 247b',
#   '0 Flock 4x-5 247c',
#   '0 Flock 4x-6 2470',
#   '0 Flock 4x-7 2478',
#   '0 Flock 4x-8 2438',
#   '0 Flock 4x-9 248c',
#   'Daqi-1, Daqi Huanjing Jiance Weixing DQ-1',
#   'Debris Removal Unprecedented Micro-Satellite',
#   'USA 167, DSCS III-A3',
#   'USA 170, DSCS III B-6',
#   'USA 135, DSCS III B-USA 13',
#   'USA 153, DSCS III B-USA',
#   'USA 113, DSCS III B-7',
#   'USA 148, DSCS III B-8',
#   'null',
#   'USA 149',
#   'USA 159',
#   'USA 176',
#   'null',
#   'Demonstration and Science Experiments',
#   'null',
#   'null',
#   'AMC-3, Americom 3, GE-3',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'TerreStar 2',
#   'null',
#   'null',
#   'G-23, Intelsat 1A-13, Telstar 13',
#   'ICO G1, DBSD G1',
#   'null',
#   'European Data Relay System-C',
#   'null',
#   'Integrated Space System, Cosmos 2510, Tundra 11L',
#   'Integrated Space System, Cosmos 2518, Tundra 12L',
#   'Integrated Space System, Cosmos 2541, Tundra 13L',
#   'Integrated Space System, Cosmos 2546, Tundra 14L',
#   'Integrated Space System, Cosmos 2552, Tunda 15L',
#   'Momentus X1',
#   'GOMS 2 [Geostationary Operational Meteorological Satellite 2]',
#   'null',
#   'null',
#   'null',
#   'ELectronic Intelligence by SAtellite',
#   'ELectronic Intelligence by SAtellite',
#   'ELectronic Intelligence by SAtellite',
#   'ELectronic Intelligence by SAtellite',
#   'End-of-Life Service by Astroscale',
#   'Electromagnetic Intelligence-gathering Satellite',
#   'Environmental Mapping and Analysis Program',
#   'Earth Observing Satellite 1, RISAT 2BR2',
#   'Earth Observing Satellite 1A, RISAT 1A',
#   'null',
#   'null',
#   'Advanced Microwave Scanning Radiometer for EOS, EOS PM-1',
#   'Cosmos 2548',
#   'Exploration of Energization and Radiation in Geospace, Arase',
#   'Earth Resources Observation Satellite',
#   'null',
#   'European Student Earth Orbiter',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   '286',
#   'null',
#   'Zhixing-1A',
#   'Euglena and Combined Regenerative Organic-Food Production in Space',
#   'Eutelsat W-2A',
#   'Satmex 6',
#   'null',
#   'Eutelsat 8 West C, Satmex 8',
#   'Satmex 9',
#   'Eutelsat 33C, Eutelsat 28A, Eurobird 1, Eurosat 1',
#   'Eutelsat 139W',
#   'Eutelsat W3C',
#   'null',
#   'GE-23, AMC-23, Worldsat 3, Americom 23',
#   'Eutelsat 48B, Eutelsat W-6A',
#   'Hot Bird 13D, Eutelsat 3C, Hot Bird 10, Atlantic Bird 4A',
#   'Eutelsat 48E, Eutelsat W-4',
#   'Eutelsat W-7',
#   'null',
#   'Atlantic Bird 3, Stellat 5',
#   'null',
#   'null',
#   'Atlantic Bird 7',
#   'Eutelsat W5A',
#   'null',
#   'null',
#   'null',
#   'Hot Bird 13E',
#   'Hot Bird 8',
#   'Hot Bird 9',
#   'Eutelsat 9A, Eurobird 9A, Hot Bird 7A',
#   'null',
#   'null',
#   'KA-SAT',
#   'null',
#   'Very High Throughput Satellite',
#   'null',
#   'AprizeSat 6',
#   'null',
#   'eXperiment for Cellular Integration Technology',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Eutelsat 53A',
#   'null',
#   'null',
#   'Eutelsat 36C',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Vt Oscar 96, VO96',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'USA 300',
#   'null',
#   'Sara Lilly and Emma,  USA 222',
#   'FMN-1',
#   'Hummingbird 1A',
#   'FY 2F',
#   'FY 2G',
#   'FY 2H',
#   'FY 3B',
#   'FY 3C',
#   'FY 3D',
#   'FY 3E',
#   'FY 4A',
#   'FY 4B',
#   'formerly GLAST',
#   'Future Imagery Architecture',
#   'Future Imagery Architecture',
#   'Future Imagery Architecture',
#   'Future Imagery Architecture',
#   'Future Imagery Architecture',
#   'Focused Investigations of Relativistic Electron Burst, Intensity, Range, and Dynamics',
#   'Focused Investigations of Relativistic Electron Burst, Intensity, Range, and Dynamics',
#   'Flying Laptop',
#   'USA 46',
#   'null',
#   'Fast On-orbit Recording of Transient Events',
#   'null',
#   'WISeSat-2',
#   'WISeSat-1',
#   'Pilot 1',
#   'LAIKA',
#   'null',
#   'null',
#   'AO 95',
#   'null',
#   'null',
#   'AO-73',
#   'null',
#   'null',
#   'Horizons 1, Galaxy 13L',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'G-25, Intelsat 1A-5, Telstar 5',
#   'G-28, Intelsat IA-8, Telstar 8',
#   'null',
#   'null',
#   'null',
#   'null',
#   '0201, Galileo 5, PRN E18',
#   '0210, Galileo 13, PRN E01',
#   '0211, Galileo 14, PRN E02',
#   '0212, Galileo 16',
#   '0213, Galileo 17',
#   '0214, Galileo 18',
#   '0215, Galileo 19',
#   '0216, Galileo 20',
#   '0217, Galileo 21',
#   '0218, Galileo 22',
#   '0219, Galileo 23',
#   '0202, Galileo 6, PRN E14',
#   '0220, Galileo 24',
#   '0221, Galileo 25',
#   '0222, Galileo 26',
#   '0223, Galileo 27',
#   '0224, Galileo 28',
#   '0203, Galileo 7, PRN E26',
#   '0204, Galileo 8, PRN E22',
#   '0205, Galileo 9, PRN E24',
#   '0206, Galileo 10, PRN E30',
#   '0207, Galileo 15',
#   '0208, Galileo 11, PRN E08',
#   '0209, Galileo 12, E09',
#   '0102, PRN E12',
#   '0101, PRN E11',
#   '0103, PRN E19',
#   '0104, PRN E20',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Cosmos 2513',
#   'Global Air Traffic Awareness and Optimizing through Spaceborne Surveillance',
#   'Global Change Observation Mission Climate, Shikisai',
#   'Globalstar Experiment And Risk Reduction Satellite 3',
#   'Globalstar Experiment And Risk Reduction Satellite',
#   'Gravitational Wave High-energy Electromagnetic Counterpart All-sky Monitor',
#   'Gravitational Wave High-energy Electromagnetic Counterpart All-sky Monitor',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Cosmos 2517',
#   'Cosmos 2540',
#   'Orbview 5',
#   'null',
#   'null',
#   'Geomagnetic Tail Laboratory',
#   'null',
#   'Iris',
#   'Hugo',
#   'Greenhouse Gas Satellite - Demonstrator, Claire',
#   'GCOM-1, Shikuzu',
#   'null',
#   'Globalstar 16',
#   'Globalstar 65',
#   'Globalstar 66',
#   'Globalstar 67',
#   'Globalstar 69',
#   'Globalstar 70',
#   'Globalstar 71',
#   'Globalstar 72',
#   'Globalstar 73, Globalstar 2-6',
#   'Globalstar 74, Globalstar 2-2',
#   'Globalstar 75, Globalstar 2-5',
#   'Globalstar 76, Globalstar 2-3',
#   'Globalstar 77, Globalstar 2-4',
#   'Globalstar 95, Globalstar 2-23',
#   'Globalstar 79, Globalstar 2-1',
#   'Globalstar 80, Globalstar 2-14',
#   'Globalstar 81, Globalstar 2-11',
#   'Globalstar 82, Globalstar 2-15',
#   'Globalstar 83, Globalstar 2-7',
#   'Globalstar 84, Globalstar 2-13',
#   'Globalstar 85, Globalstar 2-10',
#   'Globalstar 86, Globalstar 2-18',
#   'Globalstar 88, Globalstar 2-8',
#   'Globalstar 89, Globalstar 2-12',
#   'Globalstar 90, Globalstar 2-17',
#   'Globalstar 91, Globalstar 2-9',
#   'Globalstar 92, Globalstar 2-16',
#   'Globalstar 87, Globalstar 2-20',
#   'Globalstar 93, Globalstar 2-21',
#   'Globalstar 96, Globalstar 2-24',
#   'Globalstar 94, Globalstar 2-22',
#   'Globalstar 78, Globalstar 2-19',
#   'Glonass-M, Cosmos 2559',
#   'Glonass-K, Cosmos 2471',
#   'Glonass K, Cosmos 2501',
#   'Glonass M, Cosmos 2547',
#   'Glonass K, Cosmos 2557',
#   'Glonass 35-2, Cosmos 2425',
#   'Glonass 35-3, Cosmos 2426',
#   'Glonass 36-2, Cosmos 2432',
#   'Glonass 36-3, Cosmos 2433',
#   'Glonass 37-1, Cosmos 2435',
#   'Glonass 37-3, Cosmos 2436',
#   'Glonass 41-1, Cosmos 2456',
#   'Glonass 42-1, Cosmos 2459',
#   'Glonass 42-3, Cosmos 2460',
#   'Glonass 41-2, Cosmos 2457',
#   'Glonass 42-2, Cosmos 2461',
#   'Glonass 43-1, Cosmos 2464',
#   'Glonass 44-2, Cosmos 2476',
#   'Glonass 44-3, Cosmos 2477',
#   'Glonass 44-1, Cosmos 2475',
#   'Glonass-M, Cosmos 2485',
#   'Glonass-M, Cosmos 2514',
#   'Glomass-M, Cosmos 2522',
#   'Glonass-M, Cosmos 2516',
#   'Glonass-M, Cosmos 2500',
#   'Glonass-M, Cosmos 2527',
#   'Glonass-M, Cosmos 2529',
#   'Glonass-M, Cosmos 2534',
#   'Glonass-M, Cosmos 2544',
#   'Glonass-M, Cosmos 2545',
#   'null',
#   'GNSS Navigation and Occultation Measurement Satellites',
#   'GNSS Navigation and Occultation Measurement Satellites',
#   'GNSS Navigation and Occultation Measurement Satellites',
#   'Geostationary Operational Environmental Satellite, GOES-N',
#   'Geostationary Operational Environmental Satellite, GOES-O',
#   'Geostationary Operational Ennvironmental Satellite, GOES-P',
#   'Geostationary Operational Environmental Satellite GOES-R',
#   'Geostationary Operational Environmental Satellite GOES-S',
#   'Geostationary Operational Environmental Satellite GOES-T',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Gonets M21',
#   'Gonets M22',
#   'Gonets M23',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Greenhouse gases Observing Satellite-2; Ibuki-2',
#   'Gossamer 1',
#   'SES-16',
#   'Global Precipitation Measurement',
#   'Gravity Recovery and Climate Experiment Follow-on-1',
#   'Gravity Recovery and Climate Experiment Follow-on-2',
#   'Ibuki, GoSAT',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'null',
#   'Insat 4-E',
#   'null',
#   'null',
#   'null',
#   'Geosynchronous Space Situational Awareness Program, USA 254',
#   'Geosynchronous Space Situational Awareness Program, USA 270',
#   'Geosynchronous Space Situational Awareness Program, USA 271',
#   'Geosynchronous Space Situational Awareness Program, USA 324',
#   ...],
#  'Official Name': ['1HOPSAT-TD',
#   'Aalto-1',
#   'AAt-4',
#   'ABS-2',
#   'ABS-2A',
#   'ABS-3A',
#   'ABS-4',
#   'ABS-6',
#   'Adelis-Sampson 1',
#   'Adelis-Sampson 2',
#   'Adelis-Sampson 3',
#   'USA 311',
#   'USA 139',
#   'USA 171',
#   'USA 202',
#   'USA 223',
#   'USA 237',
#   'USA 268',
#   'USA 246',
#   'USA 288',
#   'USA 292',
#   'USA 298',
#   'USA 235',
#   'Aeneas',
#   'Aeolus',
#   'Aerocube 10A',
#   'Aerocube 10B',
#   'Aerocube 11A',
#   'Aerocube 11B',
#   'Aerocube 12A',
#   'Aerocube 12B',
#   'Aerocube 14A',
#   'Aerocube 14B',
#   'Aerocube 15A',
#   'Aerocube 5C',
#   'Aerocube 6A',
#   'Aerocube 6B',
#   'Aerocube 7A',
#   'Aerocube 8C',
#   'Aerocube 8D',
#   'Eutelsat 48D',
#   'AII-Bravo',
#   'AII-Charlie',
#   'AIM',
#   'AISSat-1',
#   'AISSat-2',
#   'AISTechSat-2',
#   'AISTechSat-3',
#   'Al Yah-3',
#   'Alcomsat',
#   'ALE-2',
#   'Alfa Crux',
#   'Al-Farabi-2',
#   'ALiCE',
#   'Alsat-1B',
#   'AlSat-1N',
#   'Alsat-2A',
#   'Alsat-2B',
#   'Amazonas-2',
#   'Amazonas-3',
#   'Amazonas-4A',
#   'Amazonas-5',
#   'Amazonia-1',
#   'AMC-1',
#   'AMC-11',
#   'AMC-15',
#   'AMC-18',
#   'AMC-21',
#   'AMC-4',
#   'AMC-6',
#   'AMC-8',
#   'AmGU-1',
#   'Amos 17',
#   'Amos 3',
#   'Amos 4',
#   'Amsat-Oscar 7',
#   'ANASIS-II',
#   'ANDESITE Mule',
#   'ANGELS',
#   'Angosat-2',
#   'Anik F1',
#   'Anik F1R',
#   'Anik F2',
#   'Anik F3',
#   'Anik G1',
#   'AprizeSat 1',
#   'AprizeSat 10',
#   'AprizeSat 2',
#   'AprizeSat 3',
#   'AprizeSat 4',
#   'AprizeSat 5',
#   'AprizeSat 7',
#   'AprizeSat 8',
#   'AprizeSat 9',
#   'Apstar 6C',
#   'Apstar 6D',
#   'Apstar 7',
#   'Apstar 9',
#   'Arabsat 5C',
#   'Arabsat 6A',
#   'ARCE 1A',
#   'ARCE 1B',
#   'ARCE 1C',
#   'ARCSAT',
#   'ARICA',
#   'Arktika-M1',
#   'Arkyd-6A',
#   'ArSat 1',
#   'ArSat 2',
#   'Arthur',
#   'ASELSAT',
#   'AsiaSat-5',
#   'AsiaSat-6',
#   'AsiaSat-7',
#   'AsiaSat-8',
#   'AsiaSat-9',
#   'AsiaStar',
#   'ASNARO-1',
#   'ASNARO-2',
#   'ASTERISC',
#   'Astra 1G',
#   'Astra 1KR',
#   'Astra 1L',
#   'Astra 1M',
#   'Astra 1N',
#   'Astra 2A',
#   'Astra 2C',
#   'Astra 2D',
#   'Astra 2E',
#   'Astra 2F',
#   'Astra 2G',
#   'Astra 3A',
#   'Astra 3B',
#   'Astra 5B',
#   'Astranis Demosat-2',
#   'Astrocast-0101 ',
#   'Astrocast-0102 ',
#   'Astrocast-0103 ',
#   'Astrocast-0104 ',
#   'Astrocast-0105 ',
#   'Astrocast-0201 ',
#   'Astrocast-0202   ',
#   'Astrocast-0203',
#   'Astrocast-0204 ',
#   'Astrocast-0205 ',
#   'Astrosat',
#   'AT&T T16',
#   'Athena',
#   'Athena-Fidus',
#   'Athenoxat-1',
#   'Azerspace 1/Africasat-1a',
#   'Azerspace 2/Intelsat-38',
#   'Badr 4',
#   'Badr 5',
#   'Badr 5A',
#   'Badr 6',
#   'Badr 7',
#   'Bangabandhu 1',
#   'Baoyun',
#   'Cosmos 2503',
#   'Cosmos 2515',
#   'Cosmos 2556',
#   'BDSAGR-1',
#   'BDSAT',
#   'Beesat-5',
#   'Beesat-6',
#   'Beesat-7',
#   'Beesat-8',
#   'Beesat-9',
#   'Beidou 2-12',
#   'Beidou 2-13',
#   'Beidou 2-15',
#   'Beidou 2-16',
#   'Beidou 2-17',
#   'Beidou 2-18',
#   'Beidou 3I-1S',
#   'Beidou 3I-2S',
#   'Beidou 3-M1',
#   'Beidou 3-23',
#   'Beidou 3-24',
#   'Beidou 3-25',
#   'Beidou 3M-1S',
#   'Beidou 3M-2S',
#   'Beidou DW 26',
#   'Beidou DW 27',
#   'Beidou DW 28',
#   'Beidou DW 29',
#   'Beidou DW 30',
#   'Beidou DW 31',
#   'Beidou DW 32',
#   'Beidou DW 33',
#   'Beidou DW 34',
#   'Beidou DW 35',
#   'Beidou DW 36',
#   'Beidou DW 37',
#   'Beidou DW 38',
#   'Beidou DW 39',
#   'Beidou DW 40',
#   'Beidou DW 41',
#   'Beidou DW 42',
#   'Beidou DW 43',
#   'Beidou DW 44',
#   'Beidou DW 45',
#   'Beidou DW 46',
#   'Beidou 3 IGSO-3',
#   'Beidou DW 50',
#   'Beidou DW 51',
#   'Beidou DW 52',
#   'Beidou DW 53',
#   'Beidou DW 55',
#   'Beidou G3',
#   'Beidou G4',
#   'Beidou G5',
#   'Beidou IGSO-1',
#   'Beidou IGSO-2',
#   'Beidou IGSO-3',
#   'Beidou IGSO-4',
#   'Beidou IGSO-5',
#   'Beijing-3',
#   'BeijinGalaxy-1',
#   'Belintersat-1',
#   'Bispectral InfraRed Detector 2 (Bird 2)',
#   'BIROS',
#   'BisonSat',
#   'BKA 2',
#   'BlackSky Global 1',
#   'BlackSky Global 14',
#   'BlackSky Global 15',
#   'BlackSky Global 16',
#   'BlackSky Global 17',
#   'BlackSky Global 18',
#   'BlackSky Global 2',
#   'BlackSky Global 20',
#   'BlackSky Global 3',
#   'BlackSky Global 4',
#   'BlackSky Global 7',
#   'BlackSky Global 8',
#   'BlackSky Global 9',
#   'BlackSky Pathfinder 1',
#   'Cosmos 2520',
#   'Cosmos 2526',
#   'Cosmos 2533',
#   'Cosmos 2539',
#   'Bluewalker 1',
#   'Bluewalker 3',
#   'Brazilsat B-4',
#   'Brik-II',
#   'BRIO',
#   'BRISat',
#   'BRITE-CA-1',
#   'BRITE-PL-2',
#   'BRO-1',
#   'BRO-4',
#   'BRO-7',
#   'BSAT-3A',
#   'BSAT-3B',
#   'BSAT-3C/JCSat 110-R',
#   'BSAT-4A',
#   'BSAT-4B',
#   'Buccaneer RMM',
#   'Bufeng-1A',
#   'Bufeng-1B',
#   'Bugsat-1',
#   'BulgariaSat-1',
#   'CACTUS-1',
#   'Calipso',
#   'CanX-2',
#   'CanX-4',
#   'CanX-5',
#   'CanX-7',
#   'CAPE-3',
#   'Capella-1',
#   'Capella-2',
#   'Capella-3',
#   'Capella-4',
#   'Capella-5',
#   'Capella-6',
#   'Capella-7',
#   'Capella-8',
#   'CartoSat 1',
#   'CartoSat 2',
#   'CartoSat 2A',
#   'CartoSat 2B',
#   'CartoSat 2C',
#   'CartoSat 2D',
#   'CartoSat 2E',
#   'CartoSat 2F',
#   'CartoSat 3',
#   'CAS500-1',
#   'Cassiope',
#   'USA 283',
#   'CBERS 4',
#   'CBERS 4A',
#   'CBNT-1',
#   'CBNT-2',
#   'CELTEE-1',
#   'Centauri-1',
#   'Centauri-2',
#   'Centispace-1-S1',
#   'CeReS',
#   'CERES',
#   'CERES',
#   'CERES',
#   'CE-SAT-1',
#   'CE-SAT-2B',
#   'Cesium Satellite 1',
#   'Cesium Satellite 2',
#   'CFOSat',
#   'Challenge One',
#   'Chandra X-Ray Observatory (CXO)',
#   'Changshagaoxin ',
#   'Chao Fenbianlu',
#   'Chaohu-1',
#   'CHASE',
#   'CHEOPS',
#   'CHOMPTT',
#   'Chuangxin 1-1',
#   'Chuangxin 1-2',
#   'Chuangxin 1-3',
#   'Chuangxin 1-4',
#   'Chuangxin-16A',
#   'Chuangxin-16B',
#   'Chuangxin-3',
#   'Cicero-10',
#   'Cicero-2',
#   'Cicero-2 OP1',
#   'Cicero-2 OP2',
#   'Cicero-3',
#   'Cicero-6',
#   'Cicero-7',
#   'Cicero-8',
#   'Ciel-2',
#   'CINEMA-1',
#   'CiRiS',
#   'USA 257',
#   'Cloudsat',
#   'CMS-1',
#   'CNCE-1',
#   'CNCE-3',
#   'Compass-2',
#   'COMS-1',
#   'COMSATBw-1',
#   'COMSATBw-2',
#   'Coriolis',
#   'CORVUS BC1',
#   'CORVUS BC2',
#   'CORVUS BC3',
#   'CORVUS BC4',
#   'CORVUS BC5',
#   'COSMIC 2-1',
#   'COSMIC 2-2',
#   'COSMIC 2-3',
#   'COSMIC 2-4',
#   'COSMIC 2-5',
#   'COSMIC 2-6',
#   'COSMIC-A',
#   'COSMIC-B',
#   'COSMIC-D',
#   'COSMIC-E',
#   'COSMIC-F',
#   'Cosmos 2504',
#   'Cosmos 2535',
#   'Cosmos 2536',
#   'Cosmos 2542',
#   'Cosmos 2543',
#   'Cosmos 2537',
#   'Cosmos 2538',
#   'COSMO-Skymed 1',
#   'COSMO-Skymed 2',
#   'COSMO-Skymed 3',
#   'COSMO-Skymed 4',
#   'COSMO-Skymed FM2',
#   'CP-10',
#   'Cryosat-2',
#   'CSG-1',
#   'CSIM-FD',
#   'CSO-1',
#   'CSO-2',
#   'Cubebug 2',
#   'Cubesail T',
#   'Cubesat XI-IV ',
#   'CuPID',
#   'CUTE',
#   'CYGNSS-A',
#   'CYGNSS-B',
#   'CYGNSS-C',
#   'CYNGSS-D',
#   'CYGNSS-E',
#   'CYGNSS-F',
#   'CYGNSS-G',
#   'CYGNSS-H',
#   'D2/AtlaCom-1 ',
#   'Daichi-2',
#   'DAMPE',
#   'DaVinci',
#   'Dayun',
#   'DCBB',
#   'Deimos 1',
#   'Deimos 2',
#   'Dekart',
#   'Delfi-C3',
#   'DeMi',
#   'DhabiSat-1',
#   'DHFR',
#   'Diamond Blue',
#   'Diamond Green',
#   'Diamond Red',
#   'Dido-2',
#   'Dido-3',
#   'DirecTV-10',
#   'DirecTV-11',
#   'DirecTV-12',
#   'DirecTV-14',
#   'DirecTV-15',
#   'DirecTV-5',
#   'DirecTV-8',
#   'DirecTV-9S',
#   'Diwata-2B',
#   'DLR Tubsat',
#   'DMC 3-1',
#   'DMC 3-2',
#   'DMC 3-3',
#   'DMSat-1',
#   'USA 131',
#   'USA 147',
#   'USA 172',
#   'USA 173',
#   'USA 210',
#   'Dodona',
#   'DoT-1',
#   'Dove 2k-12',
#   'Dove 2k-15',
#   'Dove 2k-19',
#   'Dove 2k-32',
#   'Dove 2k-35',
#   'Dove 2k-39',
#   'Dove 2k-40',
#   'Dove 2k-7',
#   'Dove 2p-3',
#   'Dove 2p-8',
#   'Dove 2p-9',
#   'Dove 3k-10',
#   'Dove 3k-4',
#   'Dove 3k-5',
#   'Dove 3k-7',
#   'Dove 3k-9',
#   'Dove 3m-4',
#   'Dove 3p-11',
#   'Dove  3p-12',
#   'Dove 3p-2',
#   'Dove  3p-23',
#   'Dove 3p-37',
#   'Dove 3p-32',
#   'Dove 3p-33',
#   'Dove 3p-34',
#   'Dove 3p-4',
#   'Dove 3p-46',
#   'Dove 3p-49',
#   'Dove 3p-50',
#   'Dove 3p-54',
#   'Dove 3p-55',
#   'Dove 3p-57',
#   'Dove 3p-58',
#   'Dove 3p-61',
#   'Dove 3p-64',
#   'Dove 3p-65',
#   'Dove 3p-66',
#   'Dove 3p-74',
#   'Dove 3p-76',
#   'Dove 3p-80',
#   'Dove 3r-1',
#   'Dove 3r-11',
#   'Dove 3r-12',
#   'Dove 3r-4',
#   'Dove 3r-7',
#   'Dove 3r-7',
#   'Dove 3r-9',
#   'Dove 3s-1',
#   'Dove 4a-17',
#   'Dove 4a-19',
#   'Dove 4a-2',
#   'Dove 4a-5',
#   'Dove 4a-9',
#   "Dove 4e'-1",
#   'Dove 4e’-2',
#   'Dove 4e’-3 ',
#   'Dove 4e’-4 ',
#   'Dove 4e’-5 ',
#   'Dove 4e’-6 ',
#   "Dove 4e'-8",
#   'Dove 4e’-8',
#   'Dove 4e’-9 ',
#   'Dove 4p-1',
#   'Dove 4p-10',
#   'Dove 4p-11',
#   'Dove 4p-3',
#   'Dove 4p-4',
#   'Dove 4p-5',
#   'Dove 4p-7',
#   'Dove 4s-1 ',
#   'Dove 4s-10 ',
#   'Dove 4s-11 ',
#   'Dove 4s-12 ',
#   'Dove 4s-13 ',
#   'Dove 4s-14 ',
#   'Dove 4s-15 ',
#   'Dove 4s-16 ',
#   'Dove 4s-17 ',
#   'Dove 4s-18 ',
#   'Dove 4s-19 ',
#   'Dove 4s-2 ',
#   'Dove 4s-20 ',
#   'Dove 4s-21 ',
#   'Dove 4s-22 ',
#   'Dove 4s-23 ',
#   'Dove 4s-24 ',
#   'Dove 4s-25 ',
#   'Dove 4s-27 ',
#   'Dove 4s-28 ',
#   'Dove 4s-3 ',
#   'Dove 4s-30 ',
#   'Dove 4s-31 ',
#   'Dove 4s-33 ',
#   'Dove 4s-34 ',
#   'Dove 4s-35 ',
#   'Dove 4s-36 ',
#   'Dove 4s-37 ',
#   'Dove 4s-39 ',
#   'Dove 4s-4 ',
#   'Dove 4s-41 ',
#   'Dove 4s-42 ',
#   'Dove 4s-43 ',
#   'Dove 4s-44 ',
#   'Dove 4s-45 ',
#   'Dove 4s-46 ',
#   'Dove 4s-47 ',
#   'Dove 4s-48 ',
#   'Dove 4s-5 ',
#   'Dove 4s-6 ',
#   'Dove 4s-7 ',
#   'Dove 4s-8 ',
#   'Dove 4s-9 ',
#   'Dove 4v-1',
#   'Dove 4v-10',
#   'Dove 4v-11',
#   'Dove 4v-13',
# ...
#   '43866',
#   '47305',
#   '39440',
#   '43858',
#   '27848',
#   '49264',
#   '49263',
#   '41887',
#   '41886',
#   '41891',
#   '41885',
#   '41884',
#   '41889',
#   '41890',
#   '41888',
#   '48922',
#   '39766',
#   '41173',
#   '43857',
#   '51845',
#   '40912',
#   '35681',
#   '40013',
#   '46493',
#   '32789',
#   '45916',
#   '49016',
#   '42922',
#   '42786',
#   '42785',
#   '42783',
#   '42000',
#   '46284',
#   '31862',
#   '32729',
#   '36131',
#   '40333',
#   '40663',
#   '27426',
#   '28659',
#   '29494',
#   '43678',
#   '25757',
#   '40715',
#   '40716',
#   '40717',
#   '47940',
#   '24753',
#   '25991',
#   '28054',
#   '29522',
#   '35951',
#   '51084',
#   '44399',
#   '42893',
#   '42890',
#   '42886',
#   '42870',
#   '42877',
#   '42866',
#   '42865',
#   '42862',
#   '41618',
#   '41613',
#   '41610',
#   '43905',
#   '43893',
#   '43899',
#   '43902',
#   '43906',
#   '42997',
#   '41975',
#   '41972',
#   '41966',
#   '42018',
#   '41968',
#   '42023',
#   '41990',
#   '41988',
#   '41965',
#   '42031',
#   '42001',
#   '42029',
#   '42014',
#   '42041',
#   '41978',
#   '41977',
#   '42009',
#   '42034',
#   '42028',
#   '42027',
#   '42048',
#   '42019',
#   '42026',
#   '43747',
#   '43725',
#   '43724',
#   '43733',
#   '43741',
#   '43742',
#   '43723',
#   '43769',
#   '44088',
#   '44090',
#   '44080',
#   '44095',
#   '44098',
#   '46813',
#   '46820',
#   '46819',
#   '46821',
#   '46817',
#   '46822',
#   '46814',
#   '46816',
#   '46815',
#   '44814',
#   '44808',
#   '44809',
#   '44812',
#   '44811',
#   '44818',
#   '44816',
#   '47543',
#   '47523',
#   '47462',
#   '47471',
#   '47472',
#   '47528',
#   '47521',
#   '47516',
#   '47492',
#   '47496',
#   '47500',
#   '47498',
#   '47540',
#   '47456',
#   '47452',
#   '47545',
#   '47539',
#   '47542',
#   '47495',
#   '47514',
#   '47494',
#   '47544',
#   '47475',
#   '47469',
#   '47477',
#   '47473',
#   '47530',
#   '47522',
#   '47490',
#   '47491',
#   '47698',
#   '47612',
#   '47687',
#   '47686',
#   '47688',
#   '47684',
#   '47685',
#   '47617',
#   '47515',
#   '47518',
#   '47527',
#   '47474',
#   '47478',
#   '46313',
#   '46296',
#   '46285',
#   '46297',
#   '46286',
#   '46528',
#   '46527',
#   '46529',
#   '46597',
#   '46609',
#   '46621',
#   '46735',
#   '46737',
#   '46738',
#   '46812',
#   '46825',
#   '46314',
#   '46290',
#   '46289',
#   '46291',
#   '46288',
#   '51017',
#   '51037',
#   '51049',
#   '51015',
#   '51028',
#   '51066',
#   '51010',
#   '51020',
#   '51035',
#   '51007',
#   '51046',
#   '50996',
#   '50997',
#   '51040',
#   '51003',
#   '51056',
#   '51016',
#   '51026',
#   '51045',
#   '51011',
#   '51006',
#   '51000',
#   '51041',
#   '51024',
#   '51042',
#   '51048',
#   '51039',
#   '51009',
#   '51023',
#   '51029',
#   '51064',
#   '51052',
#   '51005',
#   '51018',
#   '51027',
#   '50993',
#   '51004',
#   '51043',
#   '51065',
#   '50992',
#   '51047',
#   '52257',
#   '49398',
#   '27691',
#   '27875',
#   '25019',
#   '26575',
#   '23628',
#   '26052',
#   '52935',
#   '26356',
#   '26880',
#   '28158',
#   '43881',
#   '44344',
#   '39419',
#   '46234',
#   '24936',
#   '43790',
#   '28935',
#   '33207',
#   '36499',
#   '36792',
#   '39008',
#   '38551',
#   '41592',
#   '41893',
#   '42749',
#   '42070',
#   '27378',
#   '27854',
#   '32763',
#   '44388',
#   '44475',
#   '44047',
#   '41032',
#   '42719',
#   '44552',
#   '45608',
#   '49503',
#   '44408',
#   '37344',
#   '41105',
#   '44903',
#   '43616',
#   '38010',
#   '38008',
#   '38007',
#   '38009',
#   '47944',
#   '44078',
#   '52159',
#   '46905',
#   '51656',
#   '25994',
#   '28376',
#   '27424',
#   '47230',
#   '41896',
#   '29079',
#   '46273',
#   '43792',
#   '39233',
#   '43700',
#   '52423',
#   '52424',
#   '52426',
#   '43446',
#   '44880',
#   '47300',
#   '43807',
#   '34710',
#   '29162',
#   '40425',
#   '39122',
#   '41589',
#   '26719',
#   '28187',
#   '37836',
#   '42741',
#   '28924',
#   '38992',
#   '33750',
#   '26369',
#   '36101',
#   '39773',
#   '27460',
#   '44624',
#   '41382',
#   '37816',
#   '39020',
#   '39163',
#   '44334',
#   '40875',
#   '41310',
#   '29270',
#   '33459',
#   '28945',
#   '54048',
#   '54225',
#   '37258',
#   '45027',
#   '53765',
#   '49056',
#   '37793',
#   '40936',
#   '43819',
#   '47319',
#   '45986',
#   '45985',
#   '28707',
#   '32478',
#   '33595',
#   '39487',
#   '40277',
#   '40505',
#   '40895',
#   '41191',
#   '50001',
#   '50002',
#   '39612',
#   '39613',
#   '43775',
#   '44877',
#   '43721',
#   '47226',
#   '30776',
#   '43815',
#   '44347',
#   '45610',
#   '48924',
#   '37227',
#   '43192',
#   '38998',
#   '38049',
#   '40367',
#   '43491',
#   '37214',
#   '39260',
#   '43010',
#   '49008',
#   '41882',
#   '48808',
#   '33053',
#   '37162',
#   '38109',
#   '39462',
#   '41334',
#   '43145',
#   '40377',
#   '40378',
#   '42831',
#   '20253',
#   '42920',
#   '24920',
#   '48250',
#   '50984',
#   '50985',
#   '50990',
#   '50987',
#   '51001',
#   '50991',
#   '43770',
#   '46292',
#   '46293',
#   '39444',
#   '26038',
#   '27715',
#   '27954',
#   '28790',
#   '28884',
#   '29236',
#   '31307',
#   '32951',
#   '33376',
#   '24812',
#   '28702',
#   '46114',
#   '54026',
#   '54027',
#   '27445',
#   '40128',
#   '41549',
#   '41550',
#   '41860',
#   '41861',
#   '41862',
#   '43055',
#   '43056',
#   '43057',
#   '43058',
#   '43566',
#   '40129',
#   '43567',
#   '43564',
#   '43565',
#   '49809',
#   '49810',
#   '40544',
#   '40545',
#   '40889',
#   '40890',
#   '41859',
#   '41175',
#   '41174',
#   '37847',
#   '37846',
#   '38857',
#   '38858',
#   '39150',
#   '44622',
#   '43259',
#   '43260',
#   '43262',
#   '43461',
#   '43484',
#   '43585',
#   '46396',
#   '49492',
#   '44819',
#   '48079',
#   '52912',
#   '46610',
#   '47231',
#   '40118',
#   '41727',
#   '49495',
#   '52200',
#   '41194',
#   '49122',
#   '44703',
#   '40701',
#   '40894',
#   '45625',
#   '45794',
#   '46025',
#   '46232',
#   '45856',
#   '41121',
#   '39430',
#   '43065',
#   '51097',
#   '40657',
#   '47234',
#   '47235',
#   '52785',
#   '52786',
#   '52787',
#   '52788',
#   '52789',
#   '52790',
#   '52791',
#   '52792',
#   '52793',
#   '29252',
#   '31789',
#   '41579',
#   '44517',
#   '33331',
#   '43823',
#   '45246',
#   '22049',
#   '48962',
#   '46278',
#   '47509',
#   '41602',
#   '38337',
#   '52888',
#   '25652',
#   '31571',
#   '32265',
#   '32263',
#   '31573',
#   '32264',
#   '31576',
#   '31574',
#   '37193',
#   '37189',
#   '37192',
#   '37190',
#   '37191',
#   '39076',
#   '37188',
#   '38041',
#   '37743',
#   '38042',
#   '37739',
#   '38040',
#   '37742',
#   '38045',
#   '37740',
#   '37744',
#   '38044',
#   '37741',
#   '38043',
#   '39073',
#   '39074',
#   '39077',
#   '39075',
#   '39072',
#   '54031',
#   '37372',
#   '40315',
#   '46805',
#   '52984',
#   '29670',
#   '29671',
#   '32276',
#   '32275',
#   '32393',
#   '32395',
#   '36111',
#   '36400',
#   '36402',
#   '36112',
#   '36401',
#   '37139',
#   '37867',
#   '37868',
#   '37869',
#   '39155',
#   '41330',
#   '42939',
#   '41554',
#   '40001',
#   '43508',
#   '43687',
#   '44299',
#   '44850',
#   '45358',
#   '47346',
#   '46266',
#   '48910',
#   '52158',
#   '29155',
#   '35491',
#   '36411',
#   '41866',
#   '43226',
#   '51850',
#   '41875',
#   '39030',
#   '49816',
#   '49815',
#   '43197',
#   '43196',
#   '40552',
#   '40553',
#   '40554',
#   '39249',
#   '39250',
#   '39251',
#   '40061',
#   '40062',
#   '40063',
#   '44905',
#   '44906',
#   '44907',
#   '46486',
#   '46487',
#   '46488',
#   '47227',
#   '47228',
#   '47229',
#   '43672',
#   '50999',
#   '43178',
#   '39574',
#   '43476',
#   '43477',
#   '33492',
#   '43890',
#   '47934',
#   '47933',
#   '47936',
#   '47935',
#   '38779',
#   '43824',
#   '37746',
#   '39498',
#   '41028',
#   '40332',
#   '42815',
#   '41793',
#   '42747',
#   '52903',
#   '43698',
#   '45026',
#   '44035',
#   '40880',
#   '39234',
#   '43864',
#   '37605',
#   '40100',
#   '41744',
#   '41745',
#   '51280',
#   ...],
#  'Orbit Class': ['LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'Elliptical',
#   'LEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'GEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'GEO',
#   'MEO',
#   'MEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'Elliptical',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'MEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'Elliptical',
#   'Elliptical',
#   'Elliptical',
#   'Elliptical',
#   'Elliptical',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'Elliptical',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'Elliptical',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'Elliptical',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'Elliptical',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'Elliptical',
#   'Elliptical',
#   'Elliptical',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'Elliptical',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'MEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'LEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   'GEO',
#   ...]}
