# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import mechanicalsoup
import requests
import pandas as pd
import numpy as np

### Import Scrapers
from RadioGuyScraper import Scraper as rgs
from SatNogsScraper import Scraper as sns
from FccScraper import Scraper as fccs
from AmsatScraper import Scraper as ams
from UCSScraper import Scraper as ucs

# %%
def ScrapeAll():
    myDicts = [sns(), rgs(), fccs(), ams()]





    IDs, names, freqs, bandW, stats, descs, sources = [], [], [], [], [], [], []
    for each in myDicts:
        IDs += each['ID']
        names += each['Name']
        freqs += each['Frequency']
        bandW += each['Bandwidth/Baud']
        stats += each['Status']
        descs += each['Description']
        sources += each['Source']



    """
    Here we wish to add orbital class info if available
    """
    
    """
    orbits = ['None' for x in names]
    ucsDict = ucs()

    for nameInd in range(len(names)):
        if ((names[nameInd] in ucsDict['Friendly Name']) or (names[nameInd] in ucsDict['Official Name'])
            or (IDs[nameInd] in ucsDict['ID'])):
            if (IDs[nameInd] not in ucsDict['ID']):
                print(IDs[nameInd])
                print(names[nameInd])
            print("1")
        else:
            print("3")
    """


    """
    Sort based off Names
    """

    nameInds = np.argsort(np.array(names))
    names = list(np.array(names)[nameInds])
    IDs = list(np.array(IDs)[nameInds])
    freqs = list(np.array(freqs)[nameInds])
    bandW = list(np.array(bandW)[nameInds])
    stats = list(np.array(stats)[nameInds])
    descs = list(np.array(descs)[nameInds])
    sources = list(np.array(sources)[nameInds])

    compDict = {'ID':IDs, 'Name':names, 'Frequency [MHz]':freqs, 'Bandwidth [kHz]/Baud':bandW,
                'Status':stats, 'Description':descs, 'Source':sources}


    clones = []
    index = 0
    for each in names:
        eachInd = index + 1
        for rest in names[eachInd:]:
            if (rest == each):
                if ((freqs[index] == freqs[eachInd]) and (stats[index] == stats[eachInd]) and (descs[index] == descs[eachInd])):
                    clones += [eachInd]
                    print("CLONE", eachInd)
            eachInd += 1
        index += 1

    clones = sorted(list(set(clones)), reverse=True)


    for popInd in clones:
        for Key in compDict:
            compDict[Key].pop(popInd)
        #compDict['ID'].pop(popInd)
        #compDict['Name'].pop(popInd)
        #compDict['Frequency [MHz]'].pop(popInd)
        #compDict['Bandwidth [kHz]/Baud'].pop(popInd)
        #compDict['Status'].pop(popInd)
        #compDict['Description'].pop(popInd)
        #compDict['Source'].pop(popInd)



    return compDict

# %%
ScrapeAll()
# Out:
# CLONE 919
# CLONE 921
# CLONE 923
# CLONE 979
# CLONE 1530
# CLONE 1535
# CLONE 1537
# CLONE 1523
# CLONE 1524
# CLONE 1536
# CLONE 1527
# CLONE 1529
# CLONE 1531
# CLONE 1534
# CLONE 1539
# CLONE 1524
# CLONE 1526
# CLONE 1529
# CLONE 1531
# CLONE 1534
# CLONE 1539
# CLONE 1538
# CLONE 1531
# CLONE 1534
# CLONE 1539
# CLONE 1534
# CLONE 1539
# CLONE 1533
# CLONE 1539
# CLONE 1537
# CLONE 1543
# CLONE 1545
# CLONE 1546
# CLONE 1555
# CLONE 1547
# CLONE 1548
# CLONE 1549
# CLONE 1550
# CLONE 1551
# CLONE 1546
# CLONE 1548
# CLONE 1549
# CLONE 1550
# CLONE 1551
# CLONE 1549
# CLONE 1550
# CLONE 1551
# CLONE 1550
# CLONE 1551
# CLONE 1551
# CLONE 1560
# CLONE 1554
# CLONE 1557
# CLONE 1558
# CLONE 1558
# CLONE 1561
# CLONE 1574
# CLONE 1573
# CLONE 1565
# CLONE 1567
# CLONE 1569
# CLONE 1571
# CLONE 1576
# CLONE 1577
# CLONE 1569
# CLONE 1571
# CLONE 1576
# CLONE 1577
# CLONE 1581
# CLONE 1583
# CLONE 1571
# CLONE 1576
# CLONE 1577
# CLONE 1572
# CLONE 1582
# CLONE 1576
# CLONE 1577
# CLONE 1582
# CLONE 1579
# CLONE 1577
# CLONE 1580
# CLONE 1583
# CLONE 1588
# CLONE 1594
# CLONE 1597
# CLONE 1598
# CLONE 1603
# CLONE 1586
# CLONE 1587
# CLONE 1587
# CLONE 1594
# CLONE 1597
# CLONE 1598
# CLONE 1603
# CLONE 1591
# CLONE 1592
# CLONE 1595
# CLONE 1604
# CLONE 1597
# CLONE 1598
# CLONE 1603
# CLONE 1604
# CLONE 1599
# CLONE 1598
# CLONE 1603
# CLONE 1603
# CLONE 1602
# CLONE 1605
# CLONE 1610
# CLONE 1611
# CLONE 1612
# CLONE 1613
# CLONE 1618
# CLONE 1608
# CLONE 1609
# CLONE 1609
# CLONE 1611
# CLONE 1612
# CLONE 1613
# CLONE 1618
# CLONE 1612
# CLONE 1613
# CLONE 1618
# CLONE 1613
# CLONE 1618
# CLONE 1618
# CLONE 1619
# CLONE 1622
# CLONE 1617
# CLONE 1620
# CLONE 1622
# CLONE 1623
# CLONE 1626
# CLONE 1627
# CLONE 1650
# CLONE 1666
# CLONE 1789
# CLONE 1788
# CLONE 2263
# CLONE 2265
# CLONE 2267
# CLONE 2271
# CLONE 2291
# CLONE 2280
# CLONE 2285
# CLONE 2286
# CLONE 2294
# CLONE 2303
# CLONE 2298
# CLONE 2297
# CLONE 2313
# CLONE 2314
# CLONE 2324
# CLONE 2318
# CLONE 2329
# CLONE 2332
# CLONE 2382
# CLONE 2380
# CLONE 2650
# CLONE 2657
# CLONE 2657
# CLONE 2655
# CLONE 2656
# CLONE 2656
# CLONE 2661
# CLONE 2665
# CLONE 2665
# CLONE 2663
# CLONE 2670
# CLONE 2670
# CLONE 2673
# CLONE 2679
# CLONE 2679
# CLONE 2676
# CLONE 2677
# CLONE 2678
# CLONE 2677
# CLONE 2681
# CLONE 2682
# CLONE 2682
# CLONE 2684
# CLONE 2685
# CLONE 2685
# CLONE 2687
# CLONE 2705
# CLONE 3112
# CLONE 3117
# CLONE 3153
# CLONE 3156
# CLONE 3159
# CLONE 3398
# CLONE 3671
# CLONE 3675
# CLONE 3677
# CLONE 3681
# CLONE 3720
# CLONE 3718
# CLONE 3730
# CLONE 3731
# CLONE 3741
# CLONE 3739
# CLONE 3745
# CLONE 3752
# CLONE 3757
# CLONE 3758
# CLONE 3771
# CLONE 3773
# CLONE 3785
# CLONE 3786
# CLONE 3795
# CLONE 3796
# CLONE 4686
# CLONE 4688
# CLONE 4828
# CLONE 5339
# CLONE 5423
# CLONE 5607
# CLONE 5610
# CLONE 5610
# {'ID': ['None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'nan',
#   'nan',
#   '43466',
#   '43466',
#   '43466',
#   '43466',
#   '44316',
#   '44842',
#   '44884',
#   '49322',
#   '49322',
#   '49322',
#   '52085',
#   '52085',
#   '52420',
#   '49324',
#   '47961',
#   '43781',
#   '43728',
#   '43781',
#   '43728',
#   '41732',
#   '41732',
#   '41732',
#   '41732',
#   '46292',
#   '46293',
#   'nan',
#   '57197',
#   '57185',
#   '57197',
#   '57185',
#   '57197',
#   '57197',
#   '42775',
#   '42775',
#   '42775',
#   '42775',
#   '42729',
#   '39087',
#   '41460',
#   '41460',
#   '41460',
#   '40948',
#   '40948',
#   '40948',
#   '40948',
#   '27846',
#   '32788',
#   '39087',
#   '39087',
#   '41460',
#   '41460',
#   '40948',
#   '40948',
#   '32788',
#   '32788',
#   'None',
#   'None',
#   'None',
#   'None',
#   '44369',
#   '44369',
#   '44369',
#   '38760',
#   '38760',
#   '40389',
#   '56964',
#   '56964',
#   '56964',
#   'None',
#   '56942',
#   '41313',
#   '31135',
#   '99142',
#   '99142',
#   '99142',
#   '57208',
#   '48270',
#   '48270',
#   '56987',
#   '56987',
#   '31304',
#   '40054',
#   '40054',
#   '40054',
#   '44104',
#   '44104',
#   '44104',
#   '44104',
#   '44104',
#   '36797',
#   '39492',
#   '39492',
#   '39492',
#   '39133',
#   '39133',
#   '41465',
#   '41465',
#   '41465',
#   '41465',
#   '41465',
#   '41465',
#   '43768',
#   '43768',
#   '43768',
#   '43768',
#   '44103',
#   '44103',
#   '44103',
#   '40054',
#   '40054',
#   '19822',
#   '19822',
#   '19822',
#   '39144',
#   '39144',
#   '39467',
#   '38078',
#   '38078',
#   '1804',
#   '99380',
#   '53110',
#   '99380',
#   '41789',
#   '41789',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '44394',
#   '54366',
#   '35694',
#   '35693',
#   '44876',
#   '44876',
#   '44876',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '40034',
#   '40034',
#   '40034',
#   '34808',
#   '214',
#   '14129',
#   '14129',
#   '19216',
#   '19216',
#   '20439',
#   '20439',
#   '20439',
#   '305',
#   '21087',
#   '21087',
#   '22654',
#   '22654',
#   '22825',
#   '1293',
#   '26065',
#   '1902',
#   '1902',
#   '26609',
#   '27605',
#   '4321',
#   '4321',
#   '28375',
#   '28375',
#   '28375',
#   '28375',
#   '28375',
#   '28933',
#   '6236',
#   '6236',
#   '7530',
#   '7530',
#   '7530',
#   '7530',
#   '7530',
#   '7530',
#   '37854',
#   '37854',
#   '39444',
#   '39444',
#   '10703',
#   '10703',
#   '10703',
#   '10703',
#   '43940',
#   '41935',
#   '41935',
#   '42735',
#   '99769',
#   '46932',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '40969',
#   '40969',
#   '99058',
#   '57485',
#   '99743',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '99744',
#   'nan',
#   'nan',
#   '99745',
#   '52161',
#   '52161',
#   '52161',
#   '52161',
#   '52161',
#   '52161',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '54023',
#   '54023',
#   '54023',
#   '54023',
#   '37772',
#   '37772',
#   '37772',
#   '37772',
#   '37772',
#   '37772',
#   '37772',
#   '37772',
#   '56311',
#   '99166',
#   '43130',
#   '43130',
#   '43130',
#   '44352',
#   '44352',
#   '44352',
#   'None',
#   'None',
#   'None',
#   'None',
#   '99343',
#   '99343',
#   '99343',
#   '99343',
#   '39577',
#   '39577',
#   '40321',
#   '47441',
#   '47441',
#   '47441',
#   'None',
#   '54029',
#   'nan',
#   'nan',
#   '49395',
#   '53107',
#   '53107',
#   '41168',
#   '41168',
#   '41168',
#   '41168',
#   '41168',
#   '44830',
#   '44830',
#   '44830',
#   '42737',
#   '42737',
#   '4068',
#   '99169',
#   '99169',
#   '99169',
#   'nan',
#   'nan',
#   '43681',
#   '43681',
#   '99355',
#   '99355',
#   '99355',
#   '45261',
#   '42775',
#   '42775',
#   '42775',
#   '42729',
#   '42729',
#   '47939',
#   '47943',
#   '43600',
#   'nan',
#   'nan',
#   '31133',
#   '41313',
#   '43805',
#   '43805',
#   '52160',
#   '52160',
#   '52160',
#   '52160',
#   '52160',
#   '52160',
#   '39683',
#   '46287',
#   '46287',
#   '46287',
#   '46287',
#   '46287',
#   '44394',
#   '51841',
#   '42735',
#   '42735',
#   '41935',
#   '41935',
#   '43940',
#   '39416',
#   '39425',
#   '40018',
#   '37793',
#   '37793',
#   '37793',
#   '39416',
#   '39425',
#   '40018',
#   '57205',
#   '57205',
#   '57205',
#   '57205',
#   '39412',
#   '39412',
#   '39570',
#   '39414',
#   '39414',
#   'nan',
#   'nan',
#   '99831',
#   '45257',
#   '47719',
#   '44352',
#   '43152',
#   '53107',
#   '53107',
#   '43798',
#   '43798',
#   '43798',
#   '43798',
#   '44083',
#   '44083',
#   '44083',
#   '43798',
#   '43798',
#   '44083',
#   '44083',
#   '47488',
#   '47487',
#   '47519',
#   '48954',
#   '48955',
#   '48960',
#   '54370',
#   '54369',
#   '54368',
#   '54367',
#   '54367',
#   '41168',
#   '41168',
#   '42737',
#   '99676',
#   '48956',
#   '56312',
#   '56312',
#   '57195',
#   '57195',
#   '57195',
#   '57195',
#   '57195',
#   '45261',
#   'nan',
#   '55563',
#   '55563',
#   '55563',
#   '55563',
#   'nan',
#   '99425',
#   '48041',
#   '48041',
#   '48041',
#   '48041',
#   '48041',
#   '48041',
#   '55098',
#   '55098',
#   '55098',
#   '55098',
#   '55098',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '52175',
#   '55098',
#   '55098',
#   '55098',
#   '42736',
#   '42736',
#   '35933',
#   '35933',
#   '35933',
#   '35933',
#   'nan',
#   '99803',
#   'nan',
#   '99804',
#   'nan',
#   '99805',
#   'nan',
#   '99806',
#   '39136',
#   '39136',
#   '39136',
#   '39136',
#   '39136',
#   '39135',
#   '39135',
#   '39135',
#   '41619',
#   '41619',
#   '41619',
#   '41619',
#   '41619',
#   '99730',
#   '99730',
#   '99730',
#   '48083',
#   '99729',
#   '99729',
#   '99729',
#   '47957',
#   '99728',
#   '99728',
#   '48084',
#   '99728',
#   '99727',
#   '99727',
#   '48085',
#   '99727',
#   '44412',
#   '44412',
#   '44412',
#   '44412',
#   'nan',
#   '39142',
#   '39142',
#   '43591',
#   '43591',
#   '42823',
#   '42823',
#   '42823',
#   '42823',
#   '42823',
#   '43591',
#   '43591',
#   '43591',
#   '42821',
#   '42821',
#   '42820',
#   '42820',
#   '44330',
#   '44330',
#   '44329',
#   '44329',
#   '42822',
#   '42822',
#   '42822',
#   '42822',
#   '42822',
#   '43589',
#   '43589',
#   '43589',
#   '42824',
#   '42824',
#   '44331',
#   '44331',
#   '43590',
#   '43590',
#   '43590',
#   '41604',
#   '41604',
#   '41604',
#   '40968',
#   '39398',
#   'None',
#   'None',
#   'None',
#   'None',
#   '42786',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '53807',
#   '27422',
#   '27422',
#   'None',
#   'None',
#   'None',
#   'None',
#   '40655',
#   '40655',
#   '44355',
#   '44355',
#   '44355',
#   '44355',
#   '48876',
#   '43813',
#   '39091',
#   '39091',
#   '39091',
#   '39091',
#   '40020',
#   '39431',
#   '39431',
#   '39431',
#   '39431',
#   '39431',
#   '40119',
#   '46943',
#   '46943',
#   '46943',
#   '46943',
#   '46943',
#   '49066',
#   '49066',
#   '49066',
#   '49066',
#   '51061',
#   '51061',
#   '51061',
#   '52422',
#   '52422',
#   '52422',
#   '52174',
#   '52174',
#   '52174',
#   '55011',
#   '55011',
#   '55011',
#   '56185',
#   '56185',
#   '56185',
#   '56185',
#   '40014',
#   '40014',
#   '40014',
#   '41909',
#   '41909',
#   '41909',
#   '45857',
#   '45857',
#   '46839',
#   '46839',
#   '46839',
#   '42736',
#   '99339',
#   '99339',
#   '99339',
#   '53770',
#   '41314',
#   '49272',
#   '49272',
#   '49272',
#   '49272',
#   '55015',
#   '55015',
#   '40968',
#   '39398',
#   '42786',
#   '53807',
#   '53807',
#   '46922',
#   '46922',
#   '46922',
#   '46922',
#   '46922',
#   '46922',
#   '46922',
#   '46922',
#   '44312',
#   '40014',
#   '99759',
#   '41475',
#   '41475',
#   '41475',
#   'nan',
#   '29108',
#   '27847',
#   '32790',
#   '32790',
#   '32790',
#   '40055',
#   '40055',
#   '40056',
#   '40056',
#   '40056',
#   '99732',
#   '99732',
#   '99731',
#   '99731',
#   '47938',
#   '47938',
#   '31130',
#   '31130',
#   '31130',
#   '31130',
#   '31130',
#   '39382',
#   '39382',
#   '39382',
#   '39382',
#   '39382',
#   '47309',
#   '47309',
#   '47309',
#   '47309',
#   '47309',
#   '47309',
#   '47309',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '40718',
#   '43115',
#   '41948',
#   '41948',
#   '29710',
#   '32783',
#   '36795',
#   '41599',
#   '42767',
#   '43111',
#   '44804',
#   '44804',
#   '54816',
#   '54816',
#   '54816',
#   '54816',
#   '54816',
#   '54816',
#   '54816',
#   '41847',
#   '41847',
#   '41847',
#   '41847',
#   '41847',
#   '40903',
#   '40903',
#   '40903',
#   '40911',
#   '40911',
#   '40911',
#   '40906',
#   '40906',
#   '40906',
#   '40907',
#   '40907',
#   '40907',
#   '40909',
#   '40909',
#   '40909',
#   '40910',
#   '40910',
#   '40910',
#   '40912',
#   '40912',
#   '40908',
#   '40908',
#   '40908',
#   '40900',
#   '42761',
#   '42761',
#   '42761',
#   '42759',
#   '42759',
#   '42759',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   '54684',
#   'nan',
#   '44881',
#   '44881',
#   '44881',
#   '44881',
#   '44881',
#   '44881',
#   '44881',
#   '44881',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '44443',
#   '44443',
#   '44443',
#   '44443',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '50466',
#   '50466',
#   '50466',
#   '39265',
#   '39265',
#   '39265',
#   '32062',
#   '32062',
#   '32062',
#   '40336',
#   '44879',
#   '53111',
#   '53111',
#   '53111',
#   '52742',
#   '47966',
#   '48898',
#   '43662',
#   '42721',
#   '43669',
#   '43669',
#   '43669',
#   '39405',
#   '43855',
#   '43855',
#   '43855',
#   '41338',
#   '41338',
#   '41338',
#   '41339',
#   '41339',
#   '41339',
#   '43143',
#   '43737',
#   'None',
#   'None',
#   'None',
#   '39426',
#   '56188',
#   '56188',
#   '56188',
#   '56188',
#   '56188',
#   '56188',
#   '56188',
#   '43133',
#   '43133',
#   '27844',
#   '27844',
#   '28941',
#   '28941',
#   '28941',
#   '28941',
#   '27848',
#   '27848',
#   '28895',
#   '28895',
#   '32785',
#   '32785',
#   '32785',
#   '32791',
#   '32791',
#   '42702',
#   '42777',
#   '42777',
#   '32787',
#   '32787',
#   '32787',
#   '32787',
#   '32787',
#   '32787',
#   '42777',
#   '42777',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '39395',
#   '39395',
#   '39395',
#   '42847',
#   '42846',
#   '42846',
#   '43118',
#   '46931',
#   '42847',
#   '42846',
#   'None',
#   'None',
#   'None',
#   '22034',
#   '39059',
#   '39059',
#   '39483',
#   '39483',
#   '39484',
#   '39484',
#   '39485',
#   '39485',
#   '39761',
#   '39761',
#   '39761',
#   '39765',
#   '39765',
#   '44421',
#   '44797',
#   '53323',
#   'nan',
#   '43856',
#   '43856',
#   '47319',
#   '47319',
#   'nan',
#   '31129',
#   '31132',
#   '31132',
#   '38763',
#   '38763',
#   '35003',
#   '35003',
#   '43615',
#   '43615',
#   '44360',
#   '43856',
#   '43856',
#   '47319',
#   '38763',
#   '43615',
#   '43615',
#   '39471',
#   '44360',
#   '44360',
#   '44360',
#   '52772',
#   '52772',
#   '43793',
#   '43793',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '48274',
#   '38761',
#   '38761',
#   '31122',
#   '57202',
#   '57186',
#   '42715',
#   '42715',
#   '52950',
#   '52950',
#   '52950',
#   '52950',
#   '49275',
#   '49275',
#   ...],
#  'Name': [' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' CAPELLA-2, CAPELLA-3, and CAPELLA-4',
#   ' ECHOSTAR 19',
#   ' ECHOSTAR 19',
#   ' ECHOSTAR 19',
#   ' ECHOSTAR 19',
#   '-----  (Phase-3A)',
#   '-----  (Phase-3A)',
#   '1KUNS-PF',
#   '1KUNS-PF',
#   '1KUNS-PF',
#   '1KUNS-PF',
#   '2019-032G - Unknown Satellite',
#   '2019-087E - Unknown Satellte',
#   '2019-093F',
#   '2021-091H',
#   '2021-091H',
#   '2021-091H',
#   '2022-027B',
#   '2022-027B',
#   '2022-047AC',
#   '21091K Unknown Sat 2',
#   '3B5GSAT',
#   '3CAT-1',
#   '3CAT-1',
#   '3CAT-1',
#   '3CAT-1',
#   '3CAT-2',
#   '3CAT-2',
#   '3CAT-2',
#   '3CAT-2',
#   '3CAT-5/A, FSSCat A',
#   '3CAT-5/B, FSSCat B',
#   '4M-LXS',
#   'A-SEANSAT-PG1',
#   'A-SEANSAT-PG1',
#   'A-SEANSAT-PG1',
#   'A-SEANSAT-PG1',
#   'A-SEANSAT-PG1',
#   'A-SEANSAT-PG1',
#   'AALTO-1',
#   'AALTO-1',
#   'AALTO-1',
#   'AALTO-1',
#   'AALTO-2',
#   'AAUSAT 3',
#   'AAUSAT 4',
#   'AAUSAT 4',
#   'AAUSAT 4',
#   'AAUSAT 5',
#   'AAUSAT 5',
#   'AAUSAT 5',
#   'AAUSAT 5',
#   'AAUSAT-1',
#   'AAUSAT-2',
#   'AAUSAT-3',
#   'AAUSAT-3',
#   'AAUSAT-4',
#   'AAUSAT-4',
#   'AAUSAT-5',
#   'AAUSAT-5',
#   'AAUSAT-II',
#   'AAUSAT-II',
#   'ABS-3A',
#   'ABS-3A',
#   'ABS-3A',
#   'ABS-3A',
#   'ACRUX-1',
#   'ACRUX-1',
#   'ACRUX-1',
#   'AENEAS',
#   'AENEAS',
#   'AESP14',
#   'AFR-1',
#   'AFR-1',
#   'AFR-1',
#   'AFRISTAR-2',
#   'AFRL-XVI',
#   'AGGIESAT 4',
#   'AGILE',
#   'AHMAT-1',
#   'AHMAT-1',
#   'AHMAT-1',
#   'AHMAT-1',
#   'AII-BRAVO',
#   'AII-BRAVO',
#   'AII-DELTA',
#   'AII-DELTA',
#   'AIM',
#   'AISAT',
#   'AISAT',
#   'AISAT',
#   'AISAT-1',
#   'AISAT-1',
#   'AISAT-1',
#   'AISAT-1',
#   'AISAT-1',
#   'AISSat-1',
#   'AIST-1',
#   'AIST-1',
#   'AIST-1 (RS-41)',
#   'AIST-2 (RS-43)',
#   'AIST-2 (RS-43)',
#   'AIST-2D',
#   'AIST-2D',
#   'AIST-2D',
#   'AIST-2D',
#   'AIST-2D (RS-48)',
#   'AIST-2D (RS-48)',
#   'AISTECHSAT-2',
#   'AISTECHSAT-2',
#   'AISTECHSAT-2',
#   'AISTECHSAT-2',
#   'AISTECHSAT-3',
#   'AISTECHSAT-3',
#   'AISTECHSAT-3',
#   'AISat',
#   'AISat',
#   'AKEBONO',
#   'AKEBONO',
#   'AKEBONO',
#   'ALEXANDER (PhoneSat2)',
#   'ALEXANDER (PhoneSat2)',
#   'ALICE',
#   'ALMASat-1',
#   'ALMASat-1',
#   'ALOUETTE-2',
#   'ALPHA',
#   'ALPHA',
#   'ALPHA',
#   'ALSAT 1N',
#   'ALSat-1N',
#   'AMAZONAS NEXUS',
#   'AMAZONAS NEXUS',
#   'AMAZONAS NEXUS',
#   'AMAZONAS NEXUS',
#   'AMAZONAS NEXUS',
#   'AMAZONAS-2',
#   'AMAZONAS-2',
#   'AMAZONAS-2',
#   'AMAZONAS-2',
#   'AMAZONAS-2',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMAZONAS-3',
#   'AMC-1',
#   'AMC-1',
#   'AMC-1',
#   'AMC-1',
#   'AMC-11',
#   'AMC-11',
#   'AMC-15',
#   'AMC-15',
#   'AMC-15',
#   'AMC-15',
#   'AMC-15',
#   'AMC-15',
#   'AMC-18',
#   'AMC-18',
#   'AMC-21',
#   'AMC-21',
#   'AMC-3',
#   'AMC-3',
#   'AMC-3',
#   'AMC-3',
#   'AMC-4',
#   'AMC-4',
#   'AMC-4',
#   'AMC-6',
#   'AMC-6',
#   'AMC-8',
#   'AMC-8',
#   'AMGU-1',
#   'ANAND',
#   'ANDE-2 (Castor)',
#   'ANDE-2 (Pollux)',
#   'ANGELS',
#   'ANGELS',
#   'ANGELS',
#   'ANIK F1',
#   'ANIK F1',
#   'ANIK F1R',
#   'ANIK F1R',
#   'ANIK F1R',
#   'ANIK F1R',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F2',
#   'ANIK F3',
#   'ANIK F3',
#   'ANIK F3',
#   'ANIK F3',
#   'ANIK F3',
#   'ANIK F3',
#   'ANTELSat',
#   'ANTELSat',
#   'ANTELSat',
#   'ANUSAT',
#   'AO-1 (Oscar-1)',
#   'AO-10 (Phase-3B)',
#   'AO-10 (Phase-3B)',
#   'AO-13 (Phase-3C)',
#   'AO-13 (Phase-3C)',
#   'AO-16 (PACSAT)',
#   'AO-16 (PACSAT)',
#   'AO-16 (PACSAT)',
#   'AO-2 (Oscar-2)',
#   'AO-21 (RS-14)',
#   'AO-21 (RS-14)',
#   'AO-24 (ARSENE)',
#   'AO-24 (ARSENE)',
#   'AO-27 (EYESAT-A)',
#   'AO-3 (Oscar-3)',
#   'AO-37 (ASUSAT)',
#   'AO-4 (Oscar-4)',
#   'AO-4 (Oscar-4)',
#   'AO-40 (Phase-3D)',
#   'AO-49 (Rubin-2)',
#   'AO-5 (Oscar-5)',
#   'AO-5 (Oscar-5)',
#   'AO-51 (Echo)',
#   'AO-51 (Echo)',
#   'AO-51 (Echo)',
#   'AO-51 (Echo)',
#   'AO-51 (Echo)',
#   'AO-54 (SuitSat-1)',
#   'AO-6 (Phase-2A)',
#   'AO-6 (Phase-2A)',
#   'AO-7 (Phase-2B)',
#   'AO-7 (Phase-2B)',
#   'AO-7 (Phase-2B)',
#   'AO-7 (Phase-2B)',
#   'AO-7 (Phase-2B)',
#   'AO-7 (Phase-2B)',
#   'AO-71 (AubieSat-1)',
#   'AO-71 (AubieSat-1)',
#   'AO-73 (FUNcube-1)',
#   'AO-73 (FUNcube-1)',
#   'AO-8 (Phase-2D)',
#   'AO-8 (Phase-2D)',
#   'AO-8 (Phase-2D)',
#   'AO-8 (Phase-2D)',
#   'AOBA VELOX-IV',
#   'AOBA-VELOX 3',
#   'AOBA-VELOX 3',
#   'AOXIANG-1',
#   'APSS-1',
#   'APSS-1',
#   'APSTAR 5',
#   'APSTAR 5',
#   'APSTAR 5',
#   'APSTAR 6',
#   'APSTAR 6',
#   'ARC-1',
#   'ARC-1',
#   'ARCADE',
#   'ARCADE (INSPIRESat-4)',
#   'ARCE-1A',
#   'ARCE-1A',
#   'ARCE-1A',
#   'ARCE-1B',
#   'ARCE-1B',
#   'ARCE-1B',
#   'ARCE-1C',
#   'ARCE-1C',
#   'ARCE-1C',
#   'ARCSAT',
#   'ARCSAT',
#   'ARCSAT',
#   'ARCSAT',
#   'ARCSAT',
#   'ARCSAT',
#   'ARCTIC SATELLITE BROADBAND MISSION',
#   'ARCTIC SATELLITE BROADBAND MISSION',
#   'ARCTURUS',
#   'ARCTURUS',
#   'ARCTURUS',
#   'ARCTURUS',
#   'ARCTURUS',
#   'ARGOS-4',
#   'ARGOS-4',
#   'ARGOS-4',
#   'ARGOS-4',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARISSat-1 (SuitSat-2)',
#   'ARKSAT-1',
#   'ARKSAT-1',
#   'ARKYD 6A',
#   'ARKYD 6A',
#   'ARKYD 6A',
#   'ARMADILLO',
#   'ARMADILLO',
#   'ARMADILLO',
#   'ARSAT-2',
#   'ARSAT-2',
#   'ARSAT-2',
#   'ARSAT-2',
#   'ARTEMIS 1',
#   'ARTEMIS 1',
#   'ARTEMIS 1',
#   'ARTEMIS 1',
#   'ARTSAT1-INVADER (CO-77)',
#   'ARTSAT1-INVADER (CO-77)',
#   'ARTSAT2-DESPATCH (FO-81)',
#   'ASELSAT',
#   'ASELSAT',
#   'ASELSAT',
#   'ASIASTAR',
#   'ASO-S (Kuafu)',
#   'ASRTU-1',
#   'ASRTU-1',
#   'ASTERISC',
#   'ASTROBIO',
#   'ASTROBIO',
#   'ATHENOXAT 1',
#   'ATHENOXAT 1',
#   'ATHENOXAT 1',
#   'ATHENOXAT 1',
#   'ATHENOXAT 1',
#   'ATL-1',
#   'ATL-1',
#   'ATL-1 (MO-106)',
#   'ATLANTIS',
#   'ATLANTIS',
#   'ATS-5',
#   'AURORASAT',
#   'AURORASAT',
#   'AURORASAT',
#   'AUTcube2',
#   'AUTcube2',
#   'AUTcube2',
#   'AUTcube2',
#   'AZAADISAT',
#   'AZAADISAT',
#   'AZAADISAT',
#   'AZTECHSAT-1',
#   'Aalto-1',
#   'Aalto-1',
#   'Aalto-1',
#   'Aalto-2 (FI01)',
#   'Aalto-2 (FI01)',
#   'Adelis-Sampson 2',
#   'Adelis-Sampson 3',
#   'Aeolus',
#   'AeroCube-1',
#   'AeroCube-1',
#   'AeroCube-2',
#   'AggieSat-4',
#   'Al-Farabi-2',
#   'Al-Farabi-2',
#   'AlfaCrux',
#   'AlfaCrux',
#   'AlfaCrux',
#   'AlfaCrux',
#   'AlfaCrux',
#   'AlfaCrux',
#   'All-Star/THEIA',
#   'AmicalSat',
#   'AmicalSat',
#   'AmicalSat',
#   'AmicalSat',
#   'AmicalSat',
#   'AmurSat (AmGU-1)',
#   'Anxi Tieguanyin 1',
#   'AoXiang-1 (CN04)',
#   'AoXiang-1 (CN04)',
#   'Aoba-VELOX-III',
#   'Aoba-VELOX-III',
#   'Aoba-VELOX-IV',
#   'AprizeSat 7',
#   'AprizeSat 8',
#   'AprizeSat 9',
#   'AprizeSat-6',
#   'AprizeSat-6',
#   'AprizeSat-6',
#   'AprizeSat-7',
#   'AprizeSat-8',
#   'AprizeSat-9',
#   'ArcCube-01',
#   'ArcCube-01',
#   'ArcCube-01',
#   'ArcCube-01',
#   'ArduSat-1',
#   'ArduSat-1',
#   'ArduSat-2',
#   'ArduSat-X',
#   'ArduSat-X',
#   'Argus',
#   'Argus',
#   'Argus-2',
#   'Argus-2 (MVP-Argus)',
#   'Arktika-M1',
#   'Armadillo',
#   'Asnaro-2',
#   'AstroBio',
#   'AstroBio',
#   'Astrocast 0.1',
#   'Astrocast 0.1',
#   'Astrocast 0.1',
#   'Astrocast 0.1',
#   'Astrocast 0.2',
#   'Astrocast 0.2',
#   'Astrocast 0.2',
#   'Astrocast-0.1',
#   'Astrocast-0.1',
#   'Astrocast-0.2',
#   'Astrocast-0.2',
#   'Astrocast-0102',
#   'Astrocast-0103',
#   'Astrocast-0104',
#   'Astrocast-0201',
#   'Astrocast-0203',
#   'Astrocast-0205',
#   'Astrocast-0301',
#   'Astrocast-0302',
#   'Astrocast-0303',
#   'Astrocast-0304',
#   'Astrocast-0304',
#   'Athenoxat-1',
#   'Athenoxat-1',
#   'Atlantis (US02)',
#   'Aurora',
#   'Aurora',
#   'AuroraSat',
#   'AuroraSat',
#   'Avion Kaluga 650',
#   'Avion Kaluga 650',
#   'Avion Kaluga 650',
#   'Avion-Kaluga-650',
#   'Avion-Kaluga-650',
#   'AzTechSat-1',
#   'AzaadiSAT',
#   'AzaadiSAT-2',
#   'AzaadiSAT-2',
#   'AzaadiSAT-2',
#   'AzaadiSAT-2',
#   'BAMA-1',
#   'BAMA-1',
#   'BCCSAT 1',
#   'BCCSAT 1',
#   'BCCSAT 1',
#   'BCCSAT 1',
#   'BCCSAT-1',
#   'BCCSAT-1',
#   'BDSAT-2',
#   'BDSAT-2',
#   'BDSAT-2',
#   'BDSAT-2',
#   'BDSAT-2',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat',
#   'BDSat-2',
#   'BDSat-2',
#   'BDSat-2',
#   'BEEAGLESAT',
#   'BEEAGLESAT',
#   'BEESAT',
#   'BEESAT',
#   'BEESAT',
#   'BEESAT-1',
#   'BEESAT-10',
#   'BEESAT-10',
#   'BEESAT-11',
#   'BEESAT-11',
#   'BEESAT-12',
#   'BEESAT-12',
#   'BEESAT-13',
#   'BEESAT-13',
#   'BEESAT-2',
#   'BEESAT-2',
#   'BEESAT-2',
#   'BEESAT-2',
#   'BEESAT-2',
#   'BEESAT-3',
#   'BEESAT-3',
#   'BEESAT-3',
#   'BEESAT-4',
#   'BEESAT-4',
#   'BEESAT-4',
#   'BEESAT-4',
#   'BEESAT-4',
#   'BEESAT-5',
#   'BEESAT-5',
#   'BEESAT-5',
#   'BEESAT-5',
#   'BEESAT-6',
#   'BEESAT-6',
#   'BEESAT-6',
#   'BEESAT-6',
#   'BEESAT-7',
#   'BEESAT-7',
#   'BEESAT-7',
#   'BEESAT-7',
#   'BEESAT-8',
#   'BEESAT-8',
#   'BEESAT-8',
#   'BEESAT-8',
#   'BEESAT-9',
#   'BEESAT-9',
#   'BEESAT-9',
#   'BEESAT-9',
#   'BELIEFSAT-1',
#   'BELL (PhoneSat1)',
#   'BELL (PhoneSat1)',
#   'BHUTAN-1',
#   'BHUTAN-1',
#   'BIRD-B',
#   'BIRD-B',
#   'BIRD-B',
#   'BIRD-B (Bangladesh BRAC)',
#   'BIRD-B (Bangladesh BRAC)',
#   'BIRD-BT (BHUTAN-1)',
#   'BIRD-BT (BHUTAN-1)',
#   'BIRD-BT (BHUTAN-1)',
#   'BIRD-G (Ghana GhanaSat-1)',
#   'BIRD-G (Ghana GhanaSat-1)',
#   'BIRD-J (Japan Toki)',
#   'BIRD-J (Japan Toki)',
#   'BIRD-JPN (Uguisu)',
#   'BIRD-JPN (Uguisu)',
#   'BIRD-LKA (Raavana-1)',
#   'BIRD-LKA (Raavana-1)',
#   'BIRD-M',
#   'BIRD-M',
#   'BIRD-M',
#   'BIRD-M (Mongolia Mazaalai)',
#   'BIRD-M (Mongolia Mazaalai)',
#   'BIRD-MY (UiTMSAT-1)',
#   'BIRD-MY (UiTMSAT-1)',
#   'BIRD-MY (UiTMSAT-1)',
#   'BIRD-N (Nigeria EduSat-1)',
#   'BIRD-N (Nigeria EduSat-1)',
#   'BIRD-NPL (NepaliSat-1)',
#   'BIRD-NPL (NepaliSat-1)',
#   'BIRD-PH (MAYA-1)',
#   'BIRD-PH (MAYA-1)',
#   'BIRD-PH (MAYA-1)',
#   'BIROS',
#   'BIROS',
#   'BIROS',
#   'BISONSAT',
#   'BLACK KNIGHT-1',
#   'BLACKSKY',
#   'BLACKSKY',
#   'BLACKSKY',
#   'BLACKSKY',
#   'BLUE DIAMOND',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BLUEWALKER-3',
#   'BO-47 (IDEFIX)',
#   'BO-48 (IDEFIX)',
#   'BOEING V-BAND',
#   'BOEING V-BAND',
#   'BOEING V-BAND',
#   'BOEING V-BAND',
#   'BRICSAT-P (NO-83)',
#   'BRICSAT-P (NO-83)',
#   'BRICSAT2 (USNAP1 NO-103)',
#   'BRICSAT2 (USNAP1 NO-103)',
#   'BRICSat-2',
#   'BRICSat-2',
#   'BRIK-II',
#   'BRIO',
#   'BRITE-AUSTRIA',
#   'BRITE-AUSTRIA (CanX-3B)',
#   'BRITE-AUSTRIA (CanX-3B)',
#   'BRITE-AUSTRIA (CanX-3B)',
#   'BRITE-CA 1',
#   'BRITE-PL',
#   'BRITE-PL',
#   'BRITE-PL',
#   'BRITE-PL',
#   'BRITE-PL',
#   'BRITE-PL 2',
#   'BRO 3',
#   'BRO 3',
#   'BRO 3',
#   'BRO 3',
#   'BRO 3',
#   'BRO 4',
#   'BRO 4',
#   'BRO 4',
#   'BRO-4',
#   'BRO-5',
#   'BRO-5',
#   'BRO-5',
#   'BRO-6',
#   'BRO-6',
#   'BRO-6',
#   'BRO-7',
#   'BRO-7',
#   'BRO-7',
#   'BRO-8',
#   'BRO-8',
#   'BRO-8',
#   'BRO-9',
#   'BRO-9',
#   'BRO-9',
#   'BRO-9',
#   'BUGSAT-1',
#   'BUGSAT-1',
#   'BUGSAT-1',
#   'BY70-1',
#   'BY70-1',
#   'BY70-1',
#   'BY70-2',
#   'BY70-2',
#   'BY70-3',
#   'BY70-3',
#   'BY70-3',
#   'BeEagleSat (TR01)',
#   'BeaverCube',
#   'BeaverCube',
#   'BeaverCube',
#   'BeaverCube',
#   'Bevo-2',
#   'Binar-1',
#   'Binar-1',
#   'Binar-1',
#   'Binar-1',
#   'Birkeland',
#   'Birkeland',
#   'BisonSat',
#   'Black Knight-1',
#   'Blue  Diamond',
#   'BlueWalker-3',
#   'BlueWalker-3',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bobcat-1',
#   'Bufeng-1A',
#   'BugSat-1',
#   'CACTUS-1',
#   'CADRE',
#   'CADRE',
#   'CADRE',
#   'CAERUS',
#   'CALIPSO',
#   'CANX-1',
#   'CANX-2',
#   'CANX-2',
#   'CANX-2',
#   'CANX-4',
#   'CANX-4',
#   'CANX-5',
#   'CANX-5',
#   'CANX-5',
#   'CANYVAL-C 1U',
#   'CANYVAL-C 1U',
#   'CANYVAL-C 2U',
#   'CANYVAL-C 2U',
#   'CANYVAL-C1',
#   'CANYVAL-C2',
#   'CAPE-1',
#   'CAPE-1',
#   'CAPE-1',
#   'CAPE-1',
#   'CAPE-1',
#   'CAPE-2',
#   'CAPE-2',
#   'CAPE-2 (LO-75)',
#   'CAPE-2 (LO-75)',
#   'CAPE-2 (LO-75)',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPE-3',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-5 and CAPELLA-6',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-7 and CAPELLA-8',
#   'CAPELLA-9',
#   'CAPELLA-9',
#   'CAPELLA-9',
#   'CAPELLA-9',
#   'CAPELLA-9',
#   'CAPELLA-9',
#   'CARBONITE 1',
#   'CARBONITE 2',
#   'CARTOSAT 2D',
#   'CARTOSAT 2D',
#   'CARTOSAT-2',
#   'CARTOSAT-2A',
#   'CARTOSAT-2B',
#   'CARTOSAT-2C',
#   'CARTOSAT-2E',
#   'CARTOSAT-2F',
#   'CARTOSAT-3',
#   'CARTOSAT-3',
#   'CAS-10',
#   'CAS-10',
#   'CAS-10',
#   'CAS-10',
#   'CAS-10 (XW-4 HO-119)',
#   'CAS-10 (XW-4 HO-119)',
#   'CAS-10 (XW-4 HO-119)',
#   'CAS-2T',
#   'CAS-2T',
#   'CAS-2T & KS-1Q',
#   'CAS-2T & KS-1Q',
#   'CAS-2T & KS-1Q',
#   'CAS-3A (XW-2A)',
#   'CAS-3A (XW-2A)',
#   'CAS-3A (XW-2A)',
#   'CAS-3B (XW-2B)',
#   'CAS-3B (XW-2B)',
#   'CAS-3B (XW-2B)',
#   'CAS-3C (XW-2C)',
#   'CAS-3C (XW-2C)',
#   'CAS-3C (XW-2C)',
#   'CAS-3D (XW-2D)',
#   'CAS-3D (XW-2D)',
#   'CAS-3D (XW-2D)',
#   'CAS-3E (XW-2E)',
#   'CAS-3E (XW-2E)',
#   'CAS-3E (XW-2E)',
#   'CAS-3F (XW-2F)',
#   'CAS-3F (XW-2F)',
#   'CAS-3F (XW-2F)',
#   'CAS-3G (DCBB KAITUO-1B)',
#   'CAS-3G (DCBB KAITUO-1B)',
#   'CAS-3H (LilacSat-2)',
#   'CAS-3H (LilacSat-2)',
#   'CAS-3H (LilacSat-2)',
#   'CAS-3I (NUDT-PhoneSat)',
#   'CAS-4A (ZHUHAI-1 01)',
#   'CAS-4A (ZHUHAI-1 01)',
#   'CAS-4A (ZHUHAI-1 01)',
#   'CAS-4B (ZHUHAI-1 02)',
#   'CAS-4B (ZHUHAI-1 02)',
#   'CAS-4B (ZHUHAI-1 02)',
#   'CAS-5A',
#   'CAS-5A',
#   'CAS-5A',
#   'CAS-5A',
#   'CAS-5A',
#   'CAS-5A',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5A (FO-118)',
#   'CAS-5B',
#   'CAS-6 (TIANQIN-1 TO-108)',
#   'CAS-6 (TIANQIN-1 TO-108)',
#   'CAS-6 (TIANQIN-1 TO-108)',
#   'CAS-6 (TO-108)',
#   'CAS-6 (TO-108)',
#   'CAS-6 (TO-108)',
#   'CAS-6 (TO-108)',
#   'CAS-6 (TO-108)',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7A',
#   'CAS-7B',
#   'CAS-7B',
#   'CAS-7B (BP-1B BO-102)',
#   'CAS-7B (BP-1B BO-102)',
#   'CAS-8A',
#   'CAS-8A',
#   'CAS-8B',
#   'CAS-8B',
#   'CAS-8B',
#   'CAS-8B',
#   'CAS-8B',
#   'CAS-8B',
#   'CAS-8C',
#   'CAS-8C',
#   'CAS-8C',
#   'CAS-8C',
#   'CAS-8D',
#   'CAS-8D',
#   'CAS-8D',
#   'CAS-8D',
#   'CAS-9 (XW-3 HO-113)',
#   'CAS-9 (XW-3 HO-113)',
#   'CAS-9 (XW-3 HO-113)',
#   'CASSIOPE',
#   'CASSIOPE',
#   'CASSIOPE',
#   'CBERS-2B',
#   'CBERS-2B',
#   'CBERS-2B',
#   'CBERS-4',
#   'CBERS-4A',
#   'CELESTA',
#   'CELESTA',
#   'CELESTA',
#   'CENTAURI 5',
#   'CENTAURI-3',
#   'CENTAURI-4',
#   'CFOSAT',
#   'CHALLENGER',
#   'CHANGSHAGAOXIN',
#   'CHANGSHAGAOXIN',
#   'CHANGSHAGAOXIN',
#   'CHARGERSAT-1',
#   'CHOMPTT',
#   'CHOMPTT',
#   'CHOMPTT',
#   'CHUBUSAT-2',
#   'CHUBUSAT-2',
#   'CHUBUSAT-2',
#   'CHUBUSAT-3',
#   'CHUBUSAT-3',
#   'CHUBUSAT-3',
#   'CICERO 7',
#   'CICERO 8',
#   'CIEL-2',
#   'CIEL-2',
#   'CIEL-6i',
#   'CINEMA-3',
#   'CIRBE',
#   'CIRBE',
#   'CIRBE',
#   'CIRBE',
#   'CIRBE',
#   'CIRBE',
#   'CIRBE',
#   'CNUSAIL-1',
#   'CNUSail-1',
#   'CO-55 (CUTE-I)',
#   'CO-55 (CUTE-I)',
#   'CO-56 (CUTE1.7)',
#   'CO-56 (CUTE1.7)',
#   'CO-56 (CUTE1.7)',
#   'CO-56 (CUTE1.7)',
#   'CO-57 (XI-IV)',
#   'CO-57 (XI-IV)',
#   'CO-58 (XI-V)',
#   'CO-58 (XI-V)',
#   'CO-65 (CUTE1.7+APDII)',
#   'CO-65 (CUTE1.7+APDII)',
#   'CO-65 (CUTE1.7+APDII)',
#   'CO-66 (SEEDS-II)',
#   'CO-66 (SEEDS-II)',
#   'COLUMBIA',
#   'COMPASS 2',
#   'COMPASS 2',
#   'COMPASS-1',
#   'COMPASS-1',
#   'COMPASS-1',
#   'COMPASS-1',
#   'COMPASS-1',
#   'COMPASS-1',
#   'COMPASS-2/DragSail (DE04)',
#   'COMPASS-2/DragSail (DE04)',
#   'COMS',
#   'COMS',
#   'COMS',
#   'COMS',
#   'COMS',
#   'COPPER',
#   'COPPER',
#   'COPPER',
#   'CORVUS BC1',
#   'CORVUS BC2',
#   'CORVUS BC2',
#   'CORVUS BC3',
#   'CORVUS BC5',
#   'CORVUS-BC1',
#   'CORVUS-BC2',
#   'COSMIC-1',
#   'COSMIC-2',
#   'COSMIC-2b',
#   'COSMOS 2197',
#   'COSMOS 2484',
#   'COSMOS 2484',
#   'COSMOS 2488',
#   'COSMOS 2488',
#   'COSMOS 2489',
#   'COSMOS 2489',
#   'COSMOS 2490',
#   'COSMOS 2490',
#   'COSMOS 2496',
#   'COSMOS 2496',
#   'COSMOS 2496',
#   'COSMOS 2499',
#   'COSMOS 2499',
#   'COSMOS 2535',
#   'COSMOS 2542',
#   'COSMOS 2558',
#   'CP-1',
#   'CP-11 (ISX)',
#   'CP-11 (ISX)',
#   'CP-12 (ExoCube-2)',
#   'CP-12 (ExoCube-2)',
#   'CP-2',
#   'CP-3',
#   'CP-4',
#   'CP-4',
#   'CP-5',
#   'CP-5',
#   'CP-6',
#   'CP-6',
#   'CP-7 (DAVE)',
#   'CP-7 (DAVE)',
#   'CP-9 (LEO)',
#   'CP11 (ISX)',
#   'CP11 (ISX)',
#   'CP12(EXOCUBE-2)',
#   'CP5',
#   'CP7 (DAVE)',
#   'CP7 (DAVE)',
#   'CP8',
#   'CP9 (LEO)',
#   'CP9 (LEO)',
#   'CP9 (LEO)',
#   'CPOD FLT1',
#   'CPOD-FLT1',
#   'CSIM-FD',
#   'CSIM-FD',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (TIANHE)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSS (Tianhe)',
#   'CSSWE',
#   'CSSWE',
#   'CSTB-1',
#   'CSTP-1.1',
#   'CSTP-1.2',
#   'CSUNSat1',
#   'CSUNSat1',
#   'CTIM',
#   'CTIM',
#   'CTIM',
#   'CTIM-FD',
#   'CUAVA-1',
#   'CUAVA-1',
#   ...],
#  'Frequency [MHz]': ['8027.0',
#   '8212.5',
#   '1643.25',
#   '2036.0',
#   '1542.0',
#   '9600.0',
#   '18800.0',
#   '19950.0',
#   '28475.0',
#   '29625.0',
#   '145.81',
#   '145.89999999999998',
#   '437.3',
#   '437.3',
#   '437.3',
#   '437.3015',
#   '401.305',
#   '401.687',
#   '401.546',
#   '435.75',
#   '435.75',
#   '435.75',
#   '401.55',
#   '400.006',
#   '437.075',
#   '435.775',
#   '437.13',
#   '437.25',
#   '437.25',
#   '437.25',
#   '437.25',
#   '145.970',
#   '145.97',
#   '2401.0',
#   '2401.000',
#   '401.337',
#   '401.377',
#   '145.98',
#   '400.575',
#   '401.500',
#   '401.5',
#   '401.523',
#   '401.633828',
#   '401.523',
#   '437.22',
#   '437.22',
#   '2402.0',
#   '437.22',
#   '437.335',
#   '437.425',
#   '437.424',
#   '437.425',
#   '437.424',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.45',
#   '437.426',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.425',
#   '437.4295',
#   '437.425',
#   '6175.5',
#   '11075.0',
#   '3950.0',
#   '14125.0',
#   '437.2',
#   '437.425',
#   '437.2',
#   '437.6',
#   '437.6',
#   '437.6',
#   '436.63',
#   '2245.0',
#   '8210.0',
#   '7050.0',
#   '2230.3',
#   '436.25',
#   '149.0',
#   '437.05',
#   '437.05',
#   '435.8',
#   '437.05',
#   '401.050207',
#   '402.001',
#   '401.05',
#   '402.001',
#   '2282.5',
#   '437.513',
#   '2259.0',
#   '437.25',
#   '145.825',
#   '2259.000',
#   '2259.0',
#   '145.825',
#   '2279.0',
#   '145.825',
#   '435.265',
#   '435.265',
#   '435.265',
#   '435.215',
#   '435.265',
#   '435.315',
#   '435.365',
#   '437.235',
#   '435.27',
#   '435.31500000000005',
#   '435.315',
#   '436.6',
#   '436.73',
#   '436.73',
#   '436.73',
#   '436.73',
#   '436.73',
#   '436.73',
#   '437.511',
#   '437.25',
#   '400.45',
#   '2281.25',
#   '2280.5',
#   '437.425',
#   '2416.2',
#   '460.xxx ',
#   '2407.850',
#   '437.465',
#   '136.981',
#   '436.5',
#   '436.5',
#   '436.5',
#   '437.65',
#   '437.646',
#   '28050.0',
#   '11075.0',
#   '14125.0',
#   '11950.0',
#   '18325.0',
#   '11950.0',
#   '14125.0',
#   '13000.0',
#   '10825.0',
#   '11325.0',
#   '29750.0',
#   '11950.0',
#   '28350.0',
#   '19950.0',
#   '3950.0',
#   '18550.0',
#   '14250.0',
#   '6175.0',
#   '11950.0',
#   '14250.0',
#   '3950.0',
#   '6175.0',
#   '6175.0',
#   '3950.0',
#   '28500.0',
#   '14250.0',
#   '11950.0',
#   '29750.0',
#   '19950.0',
#   '18700.0',
#   '6175.0',
#   '3950.0',
#   '11950.0',
#   '14250.0',
#   '6175.0',
#   '3950.0',
#   '14250.0',
#   '11950.0',
#   '3950.0',
#   '14125.0',
#   '11825.0',
#   '6175.0',
#   '3950.0',
#   '6175.0',
#   '3950.0',
#   '436.25',
#   '401.9',
#   '145.825',
#   '145.825',
#   '2238.5',
#   '1698.4',
#   '465.988',
#   '14250.0',
#   '11950.0',
#   '14250.0',
#   '11950.0',
#   '6175.0',
#   '3950.0',
#   '3950.0',
#   '29625.0',
#   '6175.0',
#   '18550.0',
#   '28475.0',
#   '19950.0',
#   '11950.0',
#   '14250.0',
#   '19950.0',
#   '14250.0',
#   '11950.0',
#   '29650.0',
#   '3950.0',
#   '6175.0',
#   '437.28',
#   '2403.000',
#   '437.575',
#   '137.4',
#   '144.983',
#   '145.81',
#   '145.89999999999998',
#   '145.812',
#   '145.89999999999998',
#   '437.026',
#   '437.026',
#   '2401.143',
#   '144.983',
#   '145.822',
#   '145.8',
#   '145.975',
#   '2446.54',
#   '436.795',
#   '144.35',
#   '435.7',
#   '144.305',
#   '431.928',
#   '2401.323',
#   '145.825',
#   '144.05',
#   '29.45',
#   '435.3',
#   '435.15',
#   '2401.2',
#   '435.15',
#   '435.15',
#   '145.99',
#   '29.5',
#   '435.1',
#   '29.45',
#   '435.1',
#   '145.97',
#   '29.502',
#   '145.95',
#   '2304.1',
#   '437.473',
#   '437.475',
#   '145.95999999999998',
#   '145.935',
#   '29.45',
#   '435.095',
#   '29.402',
#   '435.15',
#   '437.225',
#   '437.371',
#   '437.375',
#   '436.15',
#   '435.1',
#   '435.1',
#   '6268.5',
#   '6694.0',
#   '3912.5',
#   '6175.0',
#   '3950.0',
#   '437.565',
#   '2440.5',
#   '437.76',
#   '437.76',
#   '2417.0',
#   '2417.000',
#   '2449.2815',
#   '2449.2815',
#   '2417.000',
#   '2417.0',
#   '2417.000',
#   '2449.2815',
#   '2417.0',
#   '267.3',
#   '314.7',
#   '312.05',
#   '268.8',
#   '2260.012',
#   '267.3',
#   '19950.0',
#   '29750.0',
#   '19900.0',
#   '29625.0',
#   '19350.0',
#   '28300.0',
#   '18500.0',
#   '1.703GHz',
#   '1703.0',
#   '465.9875',
#   '465.988',
#   '145.95',
#   '145.919',
#   '145.9182',
#   '145.939',
#   '145.93',
#   '145.919',
#   '145.95',
#   '145.939',
#   '435.45',
#   '435.45',
#   '401.5',
#   '401.989',
#   '401.51',
#   '437.525',
#   '437.525',
#   '437.525',
#   '6175.0',
#   '11950.0',
#   '3950.0',
#   '14250.0',
#   '2287.5',
#   '2245.0',
#   '2203.2',
#   '2216.5',
#   '437.2',
#   '437.325',
#   '437.325',
#   '436.95',
#   '436.95',
#   '436.95',
#   '1472.0',
#   '2207.206',
#   '436.210',
#   '435.400',
#   '2285.016',
#   '437.425',
#   '435.6',
#   '2430.0',
#   '437.485',
#   '437.485',
#   '437.485',
#   '137.5',
#   '437.175',
#   '437.175',
#   '437.175',
#   '436.39',
#   '436.3882',
#   '148.26',
#   '437.875',
#   '2428.0',
#   '437.875',
#   '437.385',
#   '437.505',
#   '437.385',
#   '437.505',
#   '437.4',
#   '437.4',
#   '437.4',
#   '437.3',
#   '437.22',
#   '2402.000',
#   '437.220',
#   '437.335',
#   '437.335',
#   '148.8',
#   '148.8',
#   '2205.0',
#   '928',
#   '902',
#   '915.0',
#   '436.25',
#   '436.5',
#   '436.5',
#   '437.225',
#   '437.125',
#   '437.225',
#   '437.1',
#   '437.100',
#   '437.1',
#   '2401.7',
#   '2415.0',
#   '436.100',
#   '436.1',
#   '2415.300',
#   '2415.0',
#   '436.25',
#   '401.734',
#   '436.150',
#   '437.640',
#   '437.375',
#   '437.375',
#   '437.225',
#   '400.585',
#   '400.553',
#   '400.552',
#   '400.591',
#   '400.591',
#   '400.591',
#   '400.585',
#   '400.553',
#   '400.552',
#   '437.6',
#   '437.6',
#   '437.6',
#   '437.6',
#   '437.325',
#   '437',
#   '437.xxx ',
#   '437.007',
#   '437.345',
#   '2403.2',
#   '437.29',
#   '437.29',
#   '437.29',
#   '1544.5',
#   '437.525',
#   '2271.604',
#   '435.600',
#   '437.425',
#   '437.147',
#   '437.3',
#   '437.15',
#   '2406.0',
#   '2406.0',
#   '437.175',
#   '437.175',
#   '2403.000',
#   '437.147',
#   '437.175',
#   '2406.000',
#   '1530.905',
#   '1530.908',
#   '1530.905',
#   '1530.905',
#   '1530.905',
#   '1530.905',
#   '1530.905',
#   '1530.905',
#   '1530.905',
#   '1.531GHz',
#   '1530.905',
#   '437.485',
#   '437.485',
#   '436.39',
#   '400.5',
#   '400.5',
#   '2428.000',
#   '437.875',
#   '435.615',
#   '435.14',
#   '435.715',
#   '435.715',
#   '435.615',
#   '437.3',
#   '437.4',
#   '437.4',
#   '437.4',
#   '437.4',
#   '437.4',
#   '437.46',
#   '437.46',
#   '435.635',
#   '435.635',
#   '435.635',
#   '435.635',
#   '435.635',
#   '435.635',
#   '436.025',
#   '436.025',
#   '145.85',
#   '145.85',
#   '436.025',
#   '145.85',
#   '145.85',
#   '436.025',
#   '145.850',
#   '436.025',
#   '436.025',
#   '436.025',
#   '145.85',
#   '436.025',
#   '436.025',
#   '145.850',
#   '436.025',
#   '437.373',
#   '437.37',
#   '435.95',
#   '435.95',
#   '435.95',
#   '436',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.9485',
#   '435.9485',
#   '435.95',
#   '435.9485',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '435.95',
#   '145.825',
#   '2416.2',
#   '437.425',
#   '145.825',
#   '437.375',
#   '437.372',
#   '437.375',
#   '437.375',
#   '437.375',
#   '437.372',
#   '437.375',
#   '145.825',
#   '437.375',
#   '437.375',
#   '437.372',
#   '437.375',
#   '437.372',
#   '437.375',
#   '437.375',
#   '437.375',
#   '437.375',
#   '437.372',
#   '437.375',
#   '437.375',
#   '437.375',
#   '437.372',
#   '437.375',
#   '145.825',
#   '437.375',
#   '437.375',
#   '437.372',
#   '437.375',
#   '437.375',
#   '145.825',
#   '437.375',
#   '437.375',
#   '437.525',
#   '437.525',
#   '2203.63',
#   '437.3755',
#   '437.345',
#   '401.1875',
#   '2067.5',
#   '1575.42',
#   '450.0',
#   '401.15',
#   '437.5',
#   '437.5',
#   '2210.0',
#   '892.0',
#   '763.0',
#   '400.575',
#   '759.7',
#   '2245.0',
#   '2026.0',
#   '145.84',
#   '435.27',
#   '39750.0',
#   '50900.0',
#   '68000.0',
#   '48700.0',
#   '435.35',
#   '437.975',
#   '145.825',
#   '435.350',
#   '145.825',
#   '437.6',
#   '2285.0',
#   '400.595',
#   '2234.4',
#   '2234.4',
#   '145.890',
#   '437.365',
#   '2234.4',
#   '437.365',
#   '2234.4',
#   '437.365',
#   '2234.400',
#   '145.89',
#   '2234.3991',
#   '401.735',
#   '401.735',
#   '401.667',
#   '401.036',
#   '401.735',
#   '401.106',
#   '401.17',
#   '401.735',
#   '401.735',
#   '401.176',
#   '401.735',
#   '401.735',
#   '401.735',
#   '401.735',
#   '401.246',
#   '401.735',
#   '401.735',
#   '401.317',
#   '401.386',
#   '401.735',
#   '401.735',
#   '401.735',
#   '401.735',
#   '401.456',
#   '401.735',
#   '437.445',
#   '437.445',
#   '437.445',
#   '436.2',
#   '436.2',
#   '436.2',
#   '436.2',
#   '436.2',
#   '437.6',
#   '437.443',
#   '437.6',
#   '437.37',
#   '1611.25',
#   '1616.25',
#   '401.5',
#   '401.5',
#   '437.325',
#   '437.292',
#   '435.810',
#   '437.292',
#   '437.292',
#   '2207.0',
#   '401.5',
#   '437.375',
#   '437.345',
#   '401.15',
#   '2210.000',
#   '437.500',
#   '436.6',
#   '436.6',
#   '436.6',
#   '436.6',
#   '436.6',
#   '436.6',
#   '436.6',
#   '436.6',
#   '401.126',
#   '437.445',
#   '434.031',
#   '437.485',
#   '437.485',
#   '3404.000',
#   '437.6',
#   '2268.467',
#   '437.88',
#   '2200.000',
#   '2407.650',
#   '437.478',
#   '2234.4',
#   '145.89',
#   '145.89',
#   '437.365',
#   '2234.4',
#   '436.33',
#   '436.33',
#   '437.5',
#   '437.5',
#   '436.33',
#   '437.5',
#   '435.247',
#   '435.245',
#   '435.245',
#   '435.247',
#   '435.245',
#   '145.825',
#   '437.325',
#   '145.825',
#   '437.325',
#   '145.822',
#   '437.325',
#   '437.325',
#   '145.825',
#   '145.825',
#   '437.325',
#   '145.825',
#   '437.325',
#   '1542.0',
#   '1643.25',
#   '9600.0',
#   '8212.5',
#   '8027.0',
#   '2036.0',
#   '2036.0',
#   '1643.25',
#   '1542.0',
#   '9600.0',
#   '8212.5',
#   '8027.0',
#   '1643.25',
#   '9600.0',
#   '8212.5',
#   '8027.0',
#   '2036.0',
#   '1542.0',
#   '2240.0',
#   '2236.675',
#   '402.761',
#   '2245.687',
#   '2245.687',
#   '2245.678',
#   '2245.687',
#   '2245.687',
#   '2245.687',
#   '2245.687',
#   '2224.8',
#   '2224.8',
#   '435.725',
#   '435.165',
#   '435.185',
#   '435.575',
#   '435.725',
#   '435.18',
#   '435.575',
#   '435.615',
#   '435.71',
#   '435.615',
#   '435.71',
#   '435.7095',
#   '145.640',
#   '145.675',
#   '145.660',
#   '145.74',
#   '145.705',
#   '145.725',
#   '145.805',
#   '145.790',
#   '145.770',
#   '145.835',
#   '145.87',
#   '145.855',
#   '145.890',
#   '145.910',
#   '145.925',
#   '145.955',
#   '145.99',
#   '145.975',
#   '437.950',
#   '145.475',
#   '437.2',
#   '437.225',
#   '144.390',
#   '437.3',
#   '145.855',
#   '145.87',
#   '145.835',
#   '145.925',
#   '145.91',
#   '145.89',
#   '435.545',
#   '435.4975',
#   '435.65',
#   '435.57',
#   '435.525',
#   '435.6',
#   '29.49',
#   '435.65',
#   '435.57',
#   '435.505',
#   '435.6',
#   '435.54',
#   '29.465',
#   '435.72',
#   '145.925',
#   '145.91',
#   '145.89',
#   '145.915',
#   '401.55',
#   '2278.328',
#   '145.91',
#   '145.89',
#   '29.45',
#   '435.365',
#   '435.4',
#   '29.425',
#   '435.48',
#   '10460',
#   '435.43',
#   '435.715',
#   '435.69',
#   '435.69',
#   '435.715',
#   '435.525',
#   '435.575',
#   '2405.1',
#   '435.61',
#   '435.75',
#   '435.58',
#   '2405.3',
#   '2405.1',
#   '435.585',
#   '435.645',
#   '435.775',
#   '2405.3',
#   '2405.3',
#   '435.59',
#   '435.68',
#   '435.8',
#   '435.18',
#   '435.725',
#   '435.575',
#   '400.032',
#   '150.012',
#   '1066.752',
#   '180.01',
#   '8320.0',
#   '8112.0',
#   '2217.121',
#   '2259.125',
#   '436.5',
#   '436.5',
#   '436.5',
#   '400.18',
#   '400.18',
#   '400.179857',
#   '2262.485',
#   '437.51',
#   '2409.0',
#   '5659.0',
#   '435.925',
#   '437.405',
#   '437.56',
#   '437.56',
#   '437.56',
#   '437.1',
#   '437.094',
#   'None',
#   '437.423',
#   'None',
#   '437.425',
#   '401.2',
#   '401.12',
#   '17550.0',
#   '12450.0',
#   '17500.0',
#   '2200.0',
#   '2402.0',
#   '2402.0',
#   '2402.000',
#   '437.250',
#   '2402.0',
#   '437.25',
#   '437.25',
#   '437.1',
#   '437.1',
#   '436.8375',
#   '437.47',
#   '437.505',
#   '437.382',
#   '437.382',
#   '437.505',
#   '436.8475',
#   '437.49',
#   '437.465',
#   '437.345',
#   '437.275',
#   '437.475',
#   '437.475',
#   '437.485',
#   '437.485',
#   '437.055',
#   '2403.0',
#   '437.3',
#   '437.275',
#   '437.405',
#   '437.275',
#   '437.275',
#   '437.275',
#   '437.405',
#   '2403.000',
#   '437.300',
#   '1687',
#   '2040.9',
#   '1695.4',
#   '2037.64',
#   '1692.14',
#   '437.29',
#   '2403.2',
#   '437.29',
#   '400.175',
#   '400.175',
#   '401.2',
#   '400.17586',
#   '400.507',
#   '400.175',
#   '400.175',
#   '2215',
#   '2264',
#   '2264',
#   '387.174837',
#   '388.687271',
#   '387.174799',
#   '388.687277',
#   '387.17481',
#   '387.174771',
#   '388.687277',
#   '388.687',
#   '387.174817',
#   '388.187269',
#   '388.687',
#   '387.174762',
#   '435.565',
#   '435.465',
#   '2281.008',
#   '2284.009',
#   '2284.0',
#   '436.845',
#   '437.15',
#   '437.15',
#   '437.15',
#   '437.15',
#   '437.325',
#   '436.845',
#   '437.325',
#   '437.325',
#   '437.405',
#   '437.405',
#   '437.365',
#   '437.365',
#   '437.15',
#   '437.15',
#   '437.505',
#   '437.15',
#   '437.15',
#   '437.15',
#   '437.405',
#   '437.15',
#   '437.15',
#   '437.27',
#   '437.505',
#   '437.505',
#   '437.505',
#   '401.18',
#   '401.18',
#   '437.25',
#   '437.25',
#   '145.985',
#   '145.98723',
#   '145.985',
#   '436.51',
#   '145.985',
#   '436.51',
#   '145.825',
#   '437.55',
#   '2250.72',
#   '2208.722',
#   '436.51',
#   '436.51',
#   '145.985',
#   '145.825',
#   '437.55',
#   '436.51',
#   '2232.22',
#   '145.985',
#   '145.985',
#   '437.349',
#   '437.349',
#   '400.0375',
#   '436.075',
#   '436.27',
#   '437.4',
#   '437.4',
#   '437.25',
#   '437.396',
#   '2402.0',
#   '437.25',
#   '76.750GHz',
#   '2440.0',
#   ...],
#  'Bandwidth [kHz]/Baud': ['1400.0 kHz',
#   '337500.0 kHz',
#   '33500.0 kHz',
#   '1400.0 kHz',
#   '34000.0 kHz',
#   '600000.0 kHz',
#   '1000000.0 kHz',
#   '500000.0 kHz',
#   '1250000.0 kHz',
#   '750000.0 kHz',
#   'None',
#   '62.0 kHz',
#   '1200.0',
#   'None',
#   '9600.0',
#   '1200.0',
#   'None',
#   'None',
#   'None',
#   '4800.0',
#   '1200.0',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   '6666.0',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   '115200.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '2400.0',
#   '2400.0',
#   '9600.0',
#   'None',
#   '1600000.0',
#   '9600.0',
#   '9600.0',
#   'None',
#   '9600.0',
#   'None',
#   '2400.0',
#   '4800.0',
#   '9600.0',
#   '1200.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '1200.0',
#   '1200.0',
#   '501000.0 kHz',
#   '250000.0 kHz',
#   '500000.0 kHz',
#   '250000.0 kHz',
#   'None',
#   '9600.0',
#   '9600.0',
#   '1200.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '50000.0 kHz',
#   'None',
#   '9600.0',
#   '2000000.0',
#   '1145.0',
#   'None',
#   '1145.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '100000.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '1200.0',
#   'None',
#   '1200.0',
#   'None',
#   '4800.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '8.5 kHz',
#   'None',
#   '4800.0',
#   'None',
#   '4800.0',
#   '9600.0',
#   'None',
#   '9600.0',
#   '4800.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '15000.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   '300000.0',
#   '9600.0',
#   'None',
#   '1100000.0 kHz',
#   '750000.0 kHz',
#   '750000.0 kHz',
#   '500000.0 kHz',
#   '950000.0 kHz',
#   '500000.0 kHz',
#   '750000.0 kHz',
#   '500000.0 kHz',
#   '250000.0 kHz',
#   '250000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '200000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '200000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '750000.0 kHz',
#   '750000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '4800.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   '600.0',
#   '800.0',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '750000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '250000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '75.0 kHz',
#   'None',
#   '75.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '25.0 kHz',
#   'None',
#   '5.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '50.0 kHz',
#   'None',
#   '50.0 kHz',
#   'None',
#   'None',
#   'None',
#   '25.0 kHz',
#   'None',
#   'None',
#   'None',
#   '10.0 kHz',
#   'None',
#   '50.0 kHz',
#   'None',
#   'None',
#   '50.0 kHz',
#   '9600.0',
#   '20.0',
#   '1200.0',
#   '9600.0',
#   '9600.0',
#   'None',
#   '837000.0 kHz',
#   '10000.0 kHz',
#   '575000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '600000.0 kHz',
#   '750000.0 kHz',
#   '100000.0 kHz',
#   '600000.0 kHz',
#   '600000.0 kHz',
#   'None',
#   'None',
#   '977.52',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '8.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   '0.0',
#   'None',
#   '19200.0',
#   '38400.0',
#   'None',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '500000.0 kHz',
#   '5000000.0',
#   '1000000.0',
#   '6000000.0',
#   '6000000.0',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   'None',
#   '40000.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   '9600.0',
#   '1000000.0',
#   '4800.0',
#   '2400.0',
#   'None',
#   '1000000.0',
#   '12500.0',
#   '1250.0',
#   'None',
#   '9600.0',
#   '9600.0',
#   '30000.0',
#   '15.0',
#   'None',
#   '1200.0',
#   'None',
#   'None',
#   '9600.0',
#   'None',
#   '1200.0',
#   'None',
#   '125000.0',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '13000.0 kHz',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '1200.0',
#   '9600.0',
#   'None',
#   '4800.0',
#   'None',
#   '1000000.0',
#   'None',
#   '1200.0',
#   'None',
#   '1000000.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   '9600.0',
#   '9600.0',
#   'None',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   '2400.0',
#   '4800.0',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '200.0 kHz',
#   'None',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '1200.0',
#   '1200.0',
#   'None',
#   'None',
#   '1200.0',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '400.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   '38400.0',
#   '9600.0',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   '1200.0',
#   '125000.0',
#   'None',
#   'None',
#   '4800.0',
#   '20.0',
#   '1200.0',
#   '9600.0',
#   '4800.0',
#   'None',
#   'None',
#   'None',
#   '9600.0',
#   '9600.0',
# ...
#   'Mode V GMSK4k8 AX.25 TLM',
#   'HF/HF   SSB',
#   'HF/UHF  SSB',
#   'VHF/UHF SSB',
#   'Beacon, HF CW',
#   '4k8 9k6 GMSK telemetry',
#   '1 Mbps  GMSK image data ',
#   'Beacon, UHF CW',
#   'Mode U CW Beacon',
#   'Mode V/U FM Transponder',
#   'VHF/UHF FM',
#   'Beacon, UHF CW',
#   'VHF/UHF SSB',
#   'Beacon, UHF CW',
#   '4K8 9K6 GMSK telemetry',
#   'VHF/UHF SSB',
#   '4K8 9K6 GMSK telemetry',
#   'Beacon, UHF CW',
#   'Inter-satellite link',
#   '192kbps GMSK image data',
#   'Beacon, UHF CW',
#   'VHF/UHF SSB',
#   '4K8 9K6 GMSK telemetry',
#   'Inter-satellite link',
#   'Inter-satellite link',
#   'Beacon, UHF CW',
#   'VHF/UHF SSB',
#   '4K8 9K6 GMSK telemetry',
#   'VHF/UHF SSB',
#   '4k8 GMSK image data',
#   'Beacon, UHF CW',
#   'CERTO 2',
#   'CERTO 1',
#   'CERTO 3',
#   '180.01 USB',
#   'Mode X 2',
#   'Mode X 1',
#   'S-band telemetry',
#   'S-band telemetry',
#   'Mode U TLM 2k4 GMSK AX25',
#   'Mode U TLM 9k6 GMSK AX25',
#   'Mode U TLM 1k2 AFSK AX25',
#   'UHF Unknown',
#   'Downlink',
#   'Downlink',
#   'Mode S Down',
#   'TLM FSK',
#   'Telem',
#   'Telem',
#   'Telem',
#   'Telem',
#   'AFSK1k2 TLM',
#   'GMSK9k6 TLM',
#   '1k2AFSK/9k6GMSK',
#   '9k6 GMSK TLM',
#   'CW Beacon',
#   'Message Exchange Service Uplink',
#   'CW Beacon',
#   'Message Exchange Service Uplink',
#   '9k6 GMSK TLM',
#   'Downlink',
#   'Downlink',
#   'nan',
#   'nan',
#   'CIEL-6i is a 17/24 GHz payload on the SES-3 satellite.',
#   '2.2 ghz',
#   'Mode S - OQPSK 2Mbps (BCT SDR-S TX)',
#   'Mode S - OQPSK 500kbps (BCT SDR-S TX)',
#   '9k6/19k2 GFSK',
#   '9k6/19k2 GFSK',
#   'Mode S - OQPSK 1Mbps (BCT SDR-S TX)',
#   'Mode U/U - GFSK 19k2 NRZ-I (SpaceQuest TRX-U)',
#   'Mode U/U - GFSK 9k6 NRZ-I (SpaceQuest TRX-U)',
#   'Mode U - GMSK9k6 Telemetry',
#   '9600bps GMSK',
#   'Beacon, 1200bps AFSK CW',
#   '1200bps AFSK CW',
#   '1200bps AFSK',
#   'Beacon, 1200bps AFSK',
#   'Beacon, 9600bps GMSK',
#   '9600bps GMSK',
#   'Beacon, 1200bps AFSK CW',
#   '1200bps AFSK CW',
#   'Beacon, 1200bps AFSK CW',
#   '1200bps AFSK CW',
#   'Beacon, 1200bps AFSK CW',
#   '1200bps AFSK CW',
#   '9600bps GMSK',
#   'Beacon, 1k2AFSK CW DigiTalker',
#   '1k2AFSK CW DigiTalker',
#   'TLM FSK9K6',
#   'TLM S-Band',
#   'TLM UHF',
#   'Mode U - MSK2k4 AX.25',
#   '1200bps AFSK CW',
#   'Beacon, 1200bps AFSK CW',
#   'Mode U - MSK4k8 AX.25',
#   'Beacon',
#   'Mode U AFSK 1k2 AX.25',
#   '1200bps AFSK',
#   '1200bps AFSK',
#   'Raw data',
#   'High resolution data',
#   'High resolution data',
#   'Selected data',
#   'Selected data',
#   'Telem',
#   '9600bps FSK',
#   'Beacon, 9600bps FSK',
#   'TLM',
#   'TLM',
#   'TLM',
#   'UHF Unknown',
#   'Downlink',
#   'FM',
#   'FM',
#   'Telemetry, sensor data',
#   'Telemetry, sensor data',
#   'Telemetry, sensor data',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'UHF Unknown',
#   'Mode U - TLM',
#   'Mode U TLM',
#   'S-band telemetry',
#   'S-band telemetry',
#   'S-band telemetry',
#   '15bps DTMF',
#   '9600bps FSK CW',
#   'Beacon, 9600bps FSK CW',
#   'Beacon, 9600bps FSK CW',
#   '9600bps FSK CW',
#   '1200bps AFSK',
#   '1200bps AFSK',
#   'Beacon, 1200bps SSB CW',
#   '1200bps SSB CW',
#   'Beacon, 1200bps AFSK CW',
#   '1200bps AFSK CW',
#   '1200bps AFSK CW',
#   'Beacon, 1200bps AFSK CW',
#   'Beacon, 9600bps FSK CW',
#   '9600bps FSK CW',
#   '9k6/19k2/38k4 FSK',
#   'CW Beacon',
#   'FSK9k6 AX.25 TLM',
#   'Mode U - FSK9k6 AX.25',
#   'Mode U - AFSK 1k2 AX25',
#   'AX.25 FSK9k6',
#   'CW',
#   'Mode U - FSK9k6 AX25',
#   'Mode U FSK9k6 AX.25',
#   'Mode U FSK19k2 AX.25',
#   'Mode U FSK38k4 AX.25',
#   'UHF Unknown',
#   'FM',
#   '9k6/19k2 GMSK',
#   'GFSK9k6 TLM',
#   'SSTV Imaging',
#   'FM',
#   'NFM Crew Voice',
#   'NFM Repeater',
#   'NFM Repeater',
#   'NFM Crew Voice',
#   '1k2_AFSK Digipeater',
#   '1k2_AFSK Digipeater',
#   'S TLM 2',
#   '2208.722',
#   '1B U/U crew voice NFM',
#   '2A V/U FM repeater NFM',
#   '2B U/V FM repeater NFM',
#   '3A V/V digipeater AFSK-FM 1200',
#   '3B U/U digipeater AFSK-FM 1200',
#   '4B U/U imaging SSTV-FM',
#   'S TLM 1',
#   '1A V/V crew voice NFM',
#   '4A V/V imaging SSTV-FM',
#   '9600bps GMSK',
#   'Mode U - FSK9k6 AX25',
#   '1200bps AFSK',
#   'LoRa',
#   'LoRa',
#   '9600bps GMSK CW',
#   'Beacon, 9600bps GMSK CW',
#   'Mode U/U - GFSK 9k6 AX.25 G3RUH (SpaceQuest TRX-U)',
#   'Mode U - GFSK 9k6 AX.25 G3RUH',
#   'Mode S - GFSK 500kbps (SpaceQuest TX-2400)',
#   '9600bps GFSK',
#   '9600bps GMSK',
#   'High Speed Downlink',
#   ...],
#  'Source': ['FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'FCC',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'FCC',
#   'FCC',
#   'FCC',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'USRadioGuy',
#   'USRadioGuy',
#   'USRadioGuy',
#   'USRadioGuy',
#   'USRadioGuy',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'USRadioGuy',
#   'USRadioGuy',
#   'USRadioGuy',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   'SatNOGS',
#   'SatNOGS',
#   'AmSAT',
#   'AmSAT',
#   'SatNOGS',
#   ...]}

# %%
#myFrame = pd.DataFrame.from_dict(ScrapeAll())
#myFrame.to_csv('SatList.csv', index=True)
